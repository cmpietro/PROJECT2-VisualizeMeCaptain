# %%
# Import dependencies
import pandas as pd

# %%
# Reference to CSv.csv"
csv_path = 'registered_weapons_by_state.csv'
firearms_df = pd.read_csv(csv_path)
firearms_df.head(10)
# Out:
#                   State Any Other Weapon 1 Destructive Device 2 Machinegun 3  \
# 0               Alabama     1,218   79,282               26,687       47,574
# 1                Alaska       328    5,032                1,650        7,107
# 2              Arkansas       637   50,465                5,469       22,554
# 3               Arizona     1,312  103,787               17,192       45,023
# 4            California     3,980  282,787               29,800       16,128
# 5              Colorado     1,023   48,481                7,385       33,538
# 6           Connecticut       948   13,508               37,311       11,919
# 7  District of Columbia        69   44,813                5,188          505
# 8              Delaware        33    3,088                  588          333
# 9               Florida     3,645  190,060               44,484       98,972
#
#   Silencer 4 Short Barreled Rifle 5 Short Barreled Shotgun 6     Total
# ...

# %%
fig, ax = plt.subplots(figsize=(8,8))
grouped_usa_df.unstack().plot(ax=ax)
plt.title("Guns")
plt.xlabel("Years")
plt.ylabel("state")
leg = ax.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-ba869975225e> in <module>
#       1
# ----> 2 fig, ax = plt.subplots(figsize=(8,8))
#       3 grouped_usa_df.unstack().plot(ax=ax)
#       4 plt.title("Guns")
#       5 plt.xlabel("Years")
#
# NameError: name 'plt' is not defined
