# %%
#
# FBI Crime Data API
#

# Dependencies and Setup
import pandas as pd
import numpy as np
import requests
import time
import csv
import json

# %matplotlib inline
import matplotlib.pyplot as plt

import os
import datetime

# Import API key
from api_keys import api_key

# %%
# api auto-generated at https://crime-data-explorer.fr.cloud.gov/api

# fbi_json = requests.get(f"https://api.usa.gov/crime/fbi/sapi/api/data/arrest/states/offense/OH/all/2010/2010?API_KEY=qjxuYoCo1z10Fvy60mTLHOcftyK9sxevJw14QbvI").json()
# fbi_json['results'][0]

fbi_json = requests.get(f"https://api.usa.gov/crime/fbi/sapi/api/summarized/estimates/states/oh/1998/2017?API_KEY=iiHnOKfno2Mgkt5AynpvPpUQTEyxE77jo1RU8PIv").json()
fbi_json
# Out:
# {'results': [{'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 2016,
#    'population': 11622554,
#    'violent_crime': 35759,
#    'homicide': 683,
#    'rape_legacy': 5589,
#    'rape_revised': 5754,
#    'robbery': 12574,
#    'aggravated_assault': 16748,
#    'property_crime': 300945,
#    'burglary': 67081,
#    'larceny': 214102,
#    'motor_vehicle_theft': 19762,
#    'arson': 2537},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 2017,
#    'population': 11658609,
#    'violent_crime': 34683,
#    'homicide': 710,
#    'rape_legacy': 0,
#    'rape_revised': 5859,
#    'robbery': 11605,
#    'aggravated_assault': 16509,
#    'property_crime': 282034,
#    'burglary': 58573,
#    'larceny': 203208,
#    'motor_vehicle_theft': 20253,
#    'arson': 1457},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 2005,
#    'population': 11470685,
#    'violent_crime': 40162,
#    'homicide': 590,
#    'rape_legacy': 4671,
#    'rape_revised': None,
#    'robbery': 18673,
#    'aggravated_assault': 16228,
#    'property_crime': 420705,
#    'burglary': 100183,
#    'larceny': 279051,
#    'motor_vehicle_theft': 41471,
#    'arson': 3330},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 1996,
#    'population': 11173000,
#    'violent_crime': 47896,
#    'homicide': 538,
#    'rape_legacy': 4617,
#    'rape_revised': None,
#    'robbery': 18336,
#    'aggravated_assault': 24405,
#    'property_crime': 449935,
#    'burglary': 93336,
#    'larceny': 311071,
#    'motor_vehicle_theft': 45528,
#    'arson': None},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 1997,
#    'population': 11186000,
#    'violent_crime': 48706,
#    'homicide': 523,
#    'rape_legacy': 4566,
#    'rape_revised': None,
#    'robbery': 17755,
#    'aggravated_assault': 25862,
#    'property_crime': 455799,
#    'burglary': 94972,
#    'larceny': 315908,
#    'motor_vehicle_theft': 45419,
#    'arson': None},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 1998,
#    'population': 11209000,
#    'violent_crime': 40628,
#    'homicide': 443,
#    'rape_legacy': 4543,
#    'rape_revised': None,
#    'robbery': 14960,
#    'aggravated_assault': 20682,
#    'property_crime': 444438,
#    'burglary': 90805,
#    'larceny': 310612,
#    'motor_vehicle_theft': 43021,
#    'arson': 3519},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 1999,
#    'population': 11256654,
#    'violent_crime': 35616,
#    'homicide': 397,
#    'rape_legacy': 4129,
#    'rape_revised': None,
#    'robbery': 14405,
#    'aggravated_assault': 16685,
#    'property_crime': 414264,
#    'burglary': 87023,
#    'larceny': 288049,
#    'motor_vehicle_theft': 39192,
#    'arson': 3327},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 2000,
#    'population': 11353140,
#    'violent_crime': 37935,
#    'homicide': 418,
#    'rape_legacy': 4271,
#    'rape_revised': None,
#    'robbery': 15610,
#    'aggravated_assault': 17636,
#    'property_crime': 420939,
#    'burglary': 88636,
#    'larceny': 293277,
#    'motor_vehicle_theft': 39026,
#    'arson': 3342},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 2001,
#    'population': 11389785,
#    'violent_crime': 40023,
#    'homicide': 452,
#    'rape_legacy': 4466,
#    'rape_revised': None,
#    'robbery': 17199,
#    'aggravated_assault': 17906,
#    'property_crime': 435115,
#    'burglary': 96910,
#    'larceny': 295976,
#    'motor_vehicle_theft': 42229,
#    'arson': 4224},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 2002,
#    'population': 11408699,
#    'violent_crime': 40128,
#    'homicide': 526,
#    'rape_legacy': 4809,
#    'rape_revised': None,
#    'robbery': 17871,
#    'aggravated_assault': 16922,
#    'property_crime': 428976,
#    'burglary': 99164,
#    'larceny': 287045,
#    'motor_vehicle_theft': 42767,
#    'arson': 3933},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 2003,
#    'population': 11437680,
#    'violent_crime': 38185,
#    'homicide': 526,
#    'rape_legacy': 4660,
#    'rape_revised': None,
#    'robbery': 16895,
#    'aggravated_assault': 16104,
#    'property_crime': 417483,
#    'burglary': 95083,
#    'larceny': 281383,
#    'motor_vehicle_theft': 41017,
#    'arson': 3238},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 2004,
#    'population': 11450143,
#    'violent_crime': 38787,
#    'homicide': 506,
#    'rape_legacy': 4744,
#    'rape_revised': None,
#    'robbery': 17429,
#    'aggravated_assault': 16108,
#    'property_crime': 419337,
#    'burglary': 96518,
#    'larceny': 282168,
#    'motor_vehicle_theft': 40651,
#    'arson': 3485},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 2006,
#    'population': 11478006,
#    'violent_crime': 41491,
#    'homicide': 560,
#    'rape_legacy': 4770,
#    'rape_revised': None,
#    'robbery': 19418,
#    'aggravated_assault': 16743,
#    'property_crime': 423334,
#    'burglary': 105639,
#    'larceny': 279718,
#    'motor_vehicle_theft': 37977,
#    'arson': 3992},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 2007,
#    'population': 11466917,
#    'violent_crime': 40759,
#    'homicide': 529,
#    'rape_legacy': 4661,
#    'rape_revised': None,
#    'robbery': 18351,
#    'aggravated_assault': 17218,
#    'property_crime': 397681,
#    'burglary': 99049,
#    'larceny': 264677,
#    'motor_vehicle_theft': 33955,
#    'arson': 3915},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 2008,
#    'population': 11485910,
#    'violent_crime': 40436,
#    'homicide': 547,
#    'rape_legacy': 4531,
#    'rape_revised': None,
#    'robbery': 18706,
#    'aggravated_assault': 16652,
#    'property_crime': 391667,
#    'burglary': 102428,
#    'larceny': 260788,
#    'motor_vehicle_theft': 28451,
#    'arson': 3657},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 2009,
#    'population': 11542645,
#    'violent_crime': 38305,
#    'homicide': 527,
#    'rape_legacy': 4119,
#    'rape_revised': None,
#    'robbery': 17670,
#    'aggravated_assault': 15989,
#    'property_crime': 376446,
#    'burglary': 104009,
#    'larceny': 249777,
#    'motor_vehicle_theft': 22660,
#    'arson': 3470},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 2010,
#    'population': 11537968,
#    'violent_crime': 36306,
#    'homicide': 479,
#    'rape_legacy': 3730,
#    'rape_revised': None,
#    'robbery': 16486,
#    'aggravated_assault': 15611,
#    'property_crime': 376836,
#    'burglary': 107125,
#    'larceny': 248581,
#    'motor_vehicle_theft': 21130,
#    'arson': 3252},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 2011,
#    'population': 11541007,
#    'violent_crime': 35218,
#    'homicide': 500,
#    'rape_legacy': 3679,
#    'rape_revised': None,
#    'robbery': 15991,
#    'aggravated_assault': 15048,
#    'property_crime': 380572,
#    'burglary': 112901,
#    'larceny': 246744,
#    'motor_vehicle_theft': 20927,
#    'arson': 3084},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 2012,
#    'population': 11553031,
#    'violent_crime': 34827,
#    'homicide': 478,
#    'rape_legacy': 3813,
#    'rape_revised': None,
#    'robbery': 15396,
#    'aggravated_assault': 15140,
#    'property_crime': 370435,
#    'burglary': 105312,
#    'larceny': 245372,
#    'motor_vehicle_theft': 19751,
#    'arson': 3555},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 1995,
#    'population': 11151000,
#    'violent_crime': 53799,
#    'homicide': 600,
#    'rape_legacy': 4835,
#    'rape_revised': None,
#    'robbery': 19931,
#    'aggravated_assault': 28433,
#    'property_crime': 437424,
#    'burglary': 93539,
#    'larceny': 297624,
#    'motor_vehicle_theft': 46261,
#    'arson': None},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 2015,
#    'population': 11605090,
#    'violent_crime': 34373,
#    'homicide': 522,
#    'rape_legacy': 3990,
#    'rape_revised': 5441,
#    'robbery': 12617,
#    'aggravated_assault': 15793,
#    'property_crime': 303743,
#    'burglary': 69994,
#    'larceny': 216354,
#    'motor_vehicle_theft': 17395,
#    'arson': 2446},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 2013,
#    'population': 11572005,
#    'violent_crime': 33722,
#    'homicide': 478,
#    'rape_legacy': 3594,
#    'rape_revised': 4391,
#    'robbery': 14483,
#    'aggravated_assault': 14370,
#    'property_crime': 338414,
#    'burglary': 91090,
#    'larceny': 227799,
#    'motor_vehicle_theft': 19525,
#    'arson': 2657},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 2014,
#    'population': 11596998,
#    'violent_crime': 33130,
#    'homicide': 464,
#    'rape_legacy': 3825,
#    'rape_revised': 5228,
#    'robbery': 12780,
#    'aggravated_assault': 14658,
#    'property_crime': 322517,
#    'burglary': 79466,
#    'larceny': 224942,
#    'motor_vehicle_theft': 18109,
#    'arson': 2161},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 1979,
#    'population': 10731000,
#    'violent_crime': 49092,
#    'homicide': 865,
#    'rape_legacy': 3409,
#    'rape_revised': None,
#    'robbery': 20909,
#    'aggravated_assault': 23909,
#    'property_crime': 501389,
#    'burglary': 138128,
#    'larceny': 316162,
#    'motor_vehicle_theft': 47099,
#    'arson': None},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 1980,
#    'population': 10766808,
#    'violent_crime': 53646,
#    'homicide': 871,
#    'rape_legacy': 3696,
#    'rape_revised': None,
#    'robbery': 24082,
#    'aggravated_assault': 24997,
#    'property_crime': 531141,
#    'burglary': 157874,
#    'larceny': 327322,
#    'motor_vehicle_theft': 45945,
#    'arson': None},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 1981,
#    'population': 10776000,
#    'violent_crime': 53509,
#    'homicide': 799,
#    'rape_legacy': 3339,
#    'rape_revised': None,
#    'robbery': 25529,
#    'aggravated_assault': 23842,
#    'property_crime': 533498,
#    'burglary': 160951,
#    'larceny': 326770,
#    'motor_vehicle_theft': 45777,
#    'arson': None},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 1982,
#    'population': 10791000,
#    'violent_crime': 47126,
#    'homicide': 676,
#    'rape_legacy': 3223,
#    'rape_revised': None,
#    'robbery': 19809,
#    'aggravated_assault': 23418,
#    'property_crime': 485468,
#    'burglary': 141316,
#    'larceny': 302962,
#    'motor_vehicle_theft': 41190,
#    'arson': None},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 1983,
#    'population': 10746000,
#    'violent_crime': 42759,
#    'homicide': 600,
#    'rape_legacy': 3387,
#    'rape_revised': None,
#    'robbery': 17132,
#    'aggravated_assault': 21640,
#    'property_crime': 441362,
#    'burglary': 124179,
#    'larceny': 280156,
#    'motor_vehicle_theft': 37027,
#    'arson': None},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 1984,
#    'population': 10752000,
#    'violent_crime': 41430,
#    'homicide': 551,
#    'rape_legacy': 3734,
#    'rape_revised': None,
#    'robbery': 15656,
#    'aggravated_assault': 21489,
#    'property_crime': 418011,
#    'burglary': 112887,
#    'larceny': 266148,
#    'motor_vehicle_theft': 38976,
#    'arson': None},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 1985,
#    'population': 10744000,
#    'violent_crime': 41000,
#    'homicide': 554,
#    'rape_legacy': 3966,
#    'rape_revised': None,
#    'robbery': 14301,
#    'aggravated_assault': 22179,
#    'property_crime': 408882,
#    'burglary': 104920,
#    'larceny': 266066,
#    'motor_vehicle_theft': 37896,
#    'arson': None},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 1986,
#    'population': 10752000,
#    'violent_crime': 45260,
#    'homicide': 595,
#    'rape_legacy': 4151,
#    'rape_revised': None,
#    'robbery': 15283,
#    'aggravated_assault': 25231,
#    'property_crime': 423387,
#    'burglary': 106212,
#    'larceny': 276779,
#    'motor_vehicle_theft': 40396,
#    'arson': None},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 1987,
#    'population': 10784000,
#    'violent_crime': 45436,
#    'homicide': 630,
#    'rape_legacy': 4305,
#    'rape_revised': None,
#    'robbery': 16511,
#    'aggravated_assault': 23990,
#    'property_crime': 447964,
#    'burglary': 114580,
#    'larceny': 292093,
#    'motor_vehicle_theft': 41291,
#    'arson': None},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 1988,
#    'population': 10872000,
#    'violent_crime': 49144,
#    'homicide': 585,
#    'rape_legacy': 4632,
#    'rape_revised': None,
#    'robbery': 17546,
#    'aggravated_assault': 26381,
#    'property_crime': 455890,
#    'burglary': 112130,
#    'larceny': 300355,
#    'motor_vehicle_theft': 43405,
#    'arson': None},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 1989,
#    'population': 10907000,
#    'violent_crime': 51109,
#    'homicide': 652,
#    'rape_legacy': 4872,
#    'rape_revised': None,
#    'robbery': 18635,
#    'aggravated_assault': 26950,
#    'property_crime': 465143,
#    'burglary': 111057,
#    'larceny': 306609,
#    'motor_vehicle_theft': 47477,
#    'arson': None},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 1990,
#    'population': 10847115,
#    'violent_crime': 54904,
#    'homicide': 663,
#    'rape_legacy': 5075,
#    'rape_revised': None,
#    'robbery': 20451,
#    'aggravated_assault': 28715,
#    'property_crime': 470469,
#    'burglary': 106575,
#    'larceny': 310673,
#    'motor_vehicle_theft': 53221,
#    'arson': None},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 1991,
#    'population': 10939000,
#    'violent_crime': 61460,
#    'homicide': 783,
#    'rape_legacy': 5748,
#    'rape_revised': None,
#    'robbery': 23536,
#    'aggravated_assault': 31393,
#    'property_crime': 489100,
#    'burglary': 115423,
#    'larceny': 318933,
#    'motor_vehicle_theft': 54744,
#    'arson': None},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 1992,
#    'population': 11016000,
#    'violent_crime': 57935,
#    'homicide': 724,
#    'rape_legacy': 5739,
#    'rape_revised': None,
#    'robbery': 21925,
#    'aggravated_assault': 29547,
#    'property_crime': 456017,
#    'burglary': 104357,
#    'larceny': 299774,
#    'motor_vehicle_theft': 51886,
#    'arson': None},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 1993,
#    'population': 11091000,
#    'violent_crime': 55915,
#    'homicide': 667,
#    'rape_legacy': 5444,
#    'rape_revised': None,
#    'robbery': 21373,
#    'aggravated_assault': 28431,
#    'property_crime': 441550,
#    'burglary': 97394,
#    'larceny': 295880,
#    'motor_vehicle_theft': 48276,
#    'arson': None},
#   {'state_id': 39,
#    'state_abbr': 'OH',
#    'year': 1994,
#    'population': 11102000,
#    'violent_crime': 53930,
#    'homicide': 662,
#    'rape_legacy': 5231,
#    'rape_revised': None,
#    'robbery': 20821,
#    'aggravated_assault': 27216,
#    'property_crime': 441380,
#    'burglary': 96175,
#    'larceny': 297792,
#    'motor_vehicle_theft': 47413,
#    'arson': None}],
#  'pagination': {'count': 39, 'page': 0, 'pages': 1, 'per_page': 0}}

# %%
# fbi_json = requests.get(f"https://api.usa.gov/crime/fbi/sapi/api/data/arrest/states/offense/OH/all/2010/2010?API_KEY=qjxuYoCo1z10Fvy60mTLHOcftyK9sxevJw14QbvI").json()
# fbi_json['results'][0]

fbi_offense = []

for key in fbi_json['results'][0]:
    print(key)

    fbi_offense.append(key)
    
fbi_offense
# Out:
# state_id
# state_abbr
# year
# population
# violent_crime
# homicide
# rape_legacy
# rape_revised
# robbery
# aggravated_assault
# property_crime
# burglary
# larceny
# motor_vehicle_theft
# arson
# ['state_id',
#  'state_abbr',
#  'year',
#  'population',
#  'violent_crime',
#  'homicide',
#  'rape_legacy',
#  'rape_revised',
#  'robbery',
#  'aggravated_assault',
#  'property_crime',
#  'burglary',
#  'larceny',
#  'motor_vehicle_theft',
#  'arson']

# %%
 len(fbi_offense)
# Out:
# 15

# %%
# /api/summarized/estimates/states/{stateAbbr}/{since}/{until} State level UCR Estimated Crime Data Endpoint
# url should look like:
# https://api.usa.gov/crime/fbi/sapi/api/data/arrest/states/offense/OH/all/2010/2010?API_KEY=qjxuYoCo1z10Fvy60mTLHOcftyK9sxevJw14QbvI").json()

states = ["AK", "AL", "AR", "AZ", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "IA", "ID", "IL", "IN", "KS", "KY", "LA", "MA", "MD", "ME", "MI", "MN", "MO", "MS", "MT", "NB", "NC", "ND", "NH", "NJ", "NM", "NV", "NY", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VA", "VT", "WA", "WI", "WV", "WY"]
    
# set up lists to hold reponse info
state_value = []
off_year = []
off_type = []
off_ct = []

# %%
base_url = "https://api.usa.gov/crime/fbi/sapi/api/summarized/estimates/states/"
state = ""
post_url = "/1998/2017?API_KEY=iiHnOKfno2Mgkt5AynpvPpUQTEyxE77jo1RU8PIv"

# %%
# Loop through the list of years and perform a request for data on each
for state in states:
    response = requests.get(base_url + state + post_url).json()['results'][0]
    for offense in fbi_offense:
        state_value.append(state)
        off_year.append(response['year'])
        off_type.append(offense)
        off_ct.append(response[offense])
        print(str(response) + "end of loop")
# Out:
# {'state_id': 1, 'state_abbr': 'AK', 'year': 1999, 'population': 619500, 'violent_crime': 3908, 'homicide': 52, 'rape_legacy': 517, 'rape_revised': None, 'robbery': 566, 'aggravated_assault': 2773, 'property_crime': 23099, 'burglary': 3787, 'larceny': 16654, 'motor_vehicle_theft': 2658, 'arson': 181}end of loop
# {'state_id': 1, 'state_abbr': 'AK', 'year': 1999, 'population': 619500, 'violent_crime': 3908, 'homicide': 52, 'rape_legacy': 517, 'rape_revised': None, 'robbery': 566, 'aggravated_assault': 2773, 'property_crime': 23099, 'burglary': 3787, 'larceny': 16654, 'motor_vehicle_theft': 2658, 'arson': 181}end of loop
# {'state_id': 1, 'state_abbr': 'AK', 'year': 1999, 'population': 619500, 'violent_crime': 3908, 'homicide': 52, 'rape_legacy': 517, 'rape_revised': None, 'robbery': 566, 'aggravated_assault': 2773, 'property_crime': 23099, 'burglary': 3787, 'larceny': 16654, 'motor_vehicle_theft': 2658, 'arson': 181}end of loop
# {'state_id': 1, 'state_abbr': 'AK', 'year': 1999, 'population': 619500, 'violent_crime': 3908, 'homicide': 52, 'rape_legacy': 517, 'rape_revised': None, 'robbery': 566, 'aggravated_assault': 2773, 'property_crime': 23099, 'burglary': 3787, 'larceny': 16654, 'motor_vehicle_theft': 2658, 'arson': 181}end of loop
# {'state_id': 1, 'state_abbr': 'AK', 'year': 1999, 'population': 619500, 'violent_crime': 3908, 'homicide': 52, 'rape_legacy': 517, 'rape_revised': None, 'robbery': 566, 'aggravated_assault': 2773, 'property_crime': 23099, 'burglary': 3787, 'larceny': 16654, 'motor_vehicle_theft': 2658, 'arson': 181}end of loop
# {'state_id': 1, 'state_abbr': 'AK', 'year': 1999, 'population': 619500, 'violent_crime': 3908, 'homicide': 52, 'rape_legacy': 517, 'rape_revised': None, 'robbery': 566, 'aggravated_assault': 2773, 'property_crime': 23099, 'burglary': 3787, 'larceny': 16654, 'motor_vehicle_theft': 2658, 'arson': 181}end of loop
# {'state_id': 1, 'state_abbr': 'AK', 'year': 1999, 'population': 619500, 'violent_crime': 3908, 'homicide': 52, 'rape_legacy': 517, 'rape_revised': None, 'robbery': 566, 'aggravated_assault': 2773, 'property_crime': 23099, 'burglary': 3787, 'larceny': 16654, 'motor_vehicle_theft': 2658, 'arson': 181}end of loop
# {'state_id': 1, 'state_abbr': 'AK', 'year': 1999, 'population': 619500, 'violent_crime': 3908, 'homicide': 52, 'rape_legacy': 517, 'rape_revised': None, 'robbery': 566, 'aggravated_assault': 2773, 'property_crime': 23099, 'burglary': 3787, 'larceny': 16654, 'motor_vehicle_theft': 2658, 'arson': 181}end of loop
# {'state_id': 1, 'state_abbr': 'AK', 'year': 1999, 'population': 619500, 'violent_crime': 3908, 'homicide': 52, 'rape_legacy': 517, 'rape_revised': None, 'robbery': 566, 'aggravated_assault': 2773, 'property_crime': 23099, 'burglary': 3787, 'larceny': 16654, 'motor_vehicle_theft': 2658, 'arson': 181}end of loop
# {'state_id': 1, 'state_abbr': 'AK', 'year': 1999, 'population': 619500, 'violent_crime': 3908, 'homicide': 52, 'rape_legacy': 517, 'rape_revised': None, 'robbery': 566, 'aggravated_assault': 2773, 'property_crime': 23099, 'burglary': 3787, 'larceny': 16654, 'motor_vehicle_theft': 2658, 'arson': 181}end of loop
# {'state_id': 1, 'state_abbr': 'AK', 'year': 1999, 'population': 619500, 'violent_crime': 3908, 'homicide': 52, 'rape_legacy': 517, 'rape_revised': None, 'robbery': 566, 'aggravated_assault': 2773, 'property_crime': 23099, 'burglary': 3787, 'larceny': 16654, 'motor_vehicle_theft': 2658, 'arson': 181}end of loop
# {'state_id': 1, 'state_abbr': 'AK', 'year': 1999, 'population': 619500, 'violent_crime': 3908, 'homicide': 52, 'rape_legacy': 517, 'rape_revised': None, 'robbery': 566, 'aggravated_assault': 2773, 'property_crime': 23099, 'burglary': 3787, 'larceny': 16654, 'motor_vehicle_theft': 2658, 'arson': 181}end of loop
# {'state_id': 1, 'state_abbr': 'AK', 'year': 1999, 'population': 619500, 'violent_crime': 3908, 'homicide': 52, 'rape_legacy': 517, 'rape_revised': None, 'robbery': 566, 'aggravated_assault': 2773, 'property_crime': 23099, 'burglary': 3787, 'larceny': 16654, 'motor_vehicle_theft': 2658, 'arson': 181}end of loop
# {'state_id': 1, 'state_abbr': 'AK', 'year': 1999, 'population': 619500, 'violent_crime': 3908, 'homicide': 52, 'rape_legacy': 517, 'rape_revised': None, 'robbery': 566, 'aggravated_assault': 2773, 'property_crime': 23099, 'burglary': 3787, 'larceny': 16654, 'motor_vehicle_theft': 2658, 'arson': 181}end of loop
# {'state_id': 1, 'state_abbr': 'AK', 'year': 1999, 'population': 619500, 'violent_crime': 3908, 'homicide': 52, 'rape_legacy': 517, 'rape_revised': None, 'robbery': 566, 'aggravated_assault': 2773, 'property_crime': 23099, 'burglary': 3787, 'larceny': 16654, 'motor_vehicle_theft': 2658, 'arson': 181}end of loop
# {'state_id': 2, 'state_abbr': 'AL', 'year': 1983, 'population': 3959000, 'violent_crime': 16471, 'homicide': 364, 'rape_legacy': 931, 'rape_revised': None, 'robbery': 3895, 'aggravated_assault': 11281, 'property_crime': 145890, 'burglary': 42485, 'larceny': 94279, 'motor_vehicle_theft': 9126, 'arson': None}end of loop
# {'state_id': 2, 'state_abbr': 'AL', 'year': 1983, 'population': 3959000, 'violent_crime': 16471, 'homicide': 364, 'rape_legacy': 931, 'rape_revised': None, 'robbery': 3895, 'aggravated_assault': 11281, 'property_crime': 145890, 'burglary': 42485, 'larceny': 94279, 'motor_vehicle_theft': 9126, 'arson': None}end of loop
# {'state_id': 2, 'state_abbr': 'AL', 'year': 1983, 'population': 3959000, 'violent_crime': 16471, 'homicide': 364, 'rape_legacy': 931, 'rape_revised': None, 'robbery': 3895, 'aggravated_assault': 11281, 'property_crime': 145890, 'burglary': 42485, 'larceny': 94279, 'motor_vehicle_theft': 9126, 'arson': None}end of loop
# {'state_id': 2, 'state_abbr': 'AL', 'year': 1983, 'population': 3959000, 'violent_crime': 16471, 'homicide': 364, 'rape_legacy': 931, 'rape_revised': None, 'robbery': 3895, 'aggravated_assault': 11281, 'property_crime': 145890, 'burglary': 42485, 'larceny': 94279, 'motor_vehicle_theft': 9126, 'arson': None}end of loop
# {'state_id': 2, 'state_abbr': 'AL', 'year': 1983, 'population': 3959000, 'violent_crime': 16471, 'homicide': 364, 'rape_legacy': 931, 'rape_revised': None, 'robbery': 3895, 'aggravated_assault': 11281, 'property_crime': 145890, 'burglary': 42485, 'larceny': 94279, 'motor_vehicle_theft': 9126, 'arson': None}end of loop
# {'state_id': 2, 'state_abbr': 'AL', 'year': 1983, 'population': 3959000, 'violent_crime': 16471, 'homicide': 364, 'rape_legacy': 931, 'rape_revised': None, 'robbery': 3895, 'aggravated_assault': 11281, 'property_crime': 145890, 'burglary': 42485, 'larceny': 94279, 'motor_vehicle_theft': 9126, 'arson': None}end of loop
# {'state_id': 2, 'state_abbr': 'AL', 'year': 1983, 'population': 3959000, 'violent_crime': 16471, 'homicide': 364, 'rape_legacy': 931, 'rape_revised': None, 'robbery': 3895, 'aggravated_assault': 11281, 'property_crime': 145890, 'burglary': 42485, 'larceny': 94279, 'motor_vehicle_theft': 9126, 'arson': None}end of loop
# {'state_id': 2, 'state_abbr': 'AL', 'year': 1983, 'population': 3959000, 'violent_crime': 16471, 'homicide': 364, 'rape_legacy': 931, 'rape_revised': None, 'robbery': 3895, 'aggravated_assault': 11281, 'property_crime': 145890, 'burglary': 42485, 'larceny': 94279, 'motor_vehicle_theft': 9126, 'arson': None}end of loop
# {'state_id': 2, 'state_abbr': 'AL', 'year': 1983, 'population': 3959000, 'violent_crime': 16471, 'homicide': 364, 'rape_legacy': 931, 'rape_revised': None, 'robbery': 3895, 'aggravated_assault': 11281, 'property_crime': 145890, 'burglary': 42485, 'larceny': 94279, 'motor_vehicle_theft': 9126, 'arson': None}end of loop
# {'state_id': 2, 'state_abbr': 'AL', 'year': 1983, 'population': 3959000, 'violent_crime': 16471, 'homicide': 364, 'rape_legacy': 931, 'rape_revised': None, 'robbery': 3895, 'aggravated_assault': 11281, 'property_crime': 145890, 'burglary': 42485, 'larceny': 94279, 'motor_vehicle_theft': 9126, 'arson': None}end of loop
# {'state_id': 2, 'state_abbr': 'AL', 'year': 1983, 'population': 3959000, 'violent_crime': 16471, 'homicide': 364, 'rape_legacy': 931, 'rape_revised': None, 'robbery': 3895, 'aggravated_assault': 11281, 'property_crime': 145890, 'burglary': 42485, 'larceny': 94279, 'motor_vehicle_theft': 9126, 'arson': None}end of loop
# {'state_id': 2, 'state_abbr': 'AL', 'year': 1983, 'population': 3959000, 'violent_crime': 16471, 'homicide': 364, 'rape_legacy': 931, 'rape_revised': None, 'robbery': 3895, 'aggravated_assault': 11281, 'property_crime': 145890, 'burglary': 42485, 'larceny': 94279, 'motor_vehicle_theft': 9126, 'arson': None}end of loop
# {'state_id': 2, 'state_abbr': 'AL', 'year': 1983, 'population': 3959000, 'violent_crime': 16471, 'homicide': 364, 'rape_legacy': 931, 'rape_revised': None, 'robbery': 3895, 'aggravated_assault': 11281, 'property_crime': 145890, 'burglary': 42485, 'larceny': 94279, 'motor_vehicle_theft': 9126, 'arson': None}end of loop
# {'state_id': 2, 'state_abbr': 'AL', 'year': 1983, 'population': 3959000, 'violent_crime': 16471, 'homicide': 364, 'rape_legacy': 931, 'rape_revised': None, 'robbery': 3895, 'aggravated_assault': 11281, 'property_crime': 145890, 'burglary': 42485, 'larceny': 94279, 'motor_vehicle_theft': 9126, 'arson': None}end of loop
# {'state_id': 2, 'state_abbr': 'AL', 'year': 1983, 'population': 3959000, 'violent_crime': 16471, 'homicide': 364, 'rape_legacy': 931, 'rape_revised': None, 'robbery': 3895, 'aggravated_assault': 11281, 'property_crime': 145890, 'burglary': 42485, 'larceny': 94279, 'motor_vehicle_theft': 9126, 'arson': None}end of loop
# {'state_id': 3, 'state_abbr': 'AR', 'year': 1996, 'population': 2510000, 'violent_crime': 13161, 'homicide': 219, 'rape_legacy': 1046, 'rape_revised': None, 'robbery': 2864, 'aggravated_assault': 9032, 'property_crime': 104790, 'burglary': 23925, 'larceny': 73010, 'motor_vehicle_theft': 7855, 'arson': None}end of loop
# {'state_id': 3, 'state_abbr': 'AR', 'year': 1996, 'population': 2510000, 'violent_crime': 13161, 'homicide': 219, 'rape_legacy': 1046, 'rape_revised': None, 'robbery': 2864, 'aggravated_assault': 9032, 'property_crime': 104790, 'burglary': 23925, 'larceny': 73010, 'motor_vehicle_theft': 7855, 'arson': None}end of loop
# {'state_id': 3, 'state_abbr': 'AR', 'year': 1996, 'population': 2510000, 'violent_crime': 13161, 'homicide': 219, 'rape_legacy': 1046, 'rape_revised': None, 'robbery': 2864, 'aggravated_assault': 9032, 'property_crime': 104790, 'burglary': 23925, 'larceny': 73010, 'motor_vehicle_theft': 7855, 'arson': None}end of loop
# {'state_id': 3, 'state_abbr': 'AR', 'year': 1996, 'population': 2510000, 'violent_crime': 13161, 'homicide': 219, 'rape_legacy': 1046, 'rape_revised': None, 'robbery': 2864, 'aggravated_assault': 9032, 'property_crime': 104790, 'burglary': 23925, 'larceny': 73010, 'motor_vehicle_theft': 7855, 'arson': None}end of loop
# {'state_id': 3, 'state_abbr': 'AR', 'year': 1996, 'population': 2510000, 'violent_crime': 13161, 'homicide': 219, 'rape_legacy': 1046, 'rape_revised': None, 'robbery': 2864, 'aggravated_assault': 9032, 'property_crime': 104790, 'burglary': 23925, 'larceny': 73010, 'motor_vehicle_theft': 7855, 'arson': None}end of loop
# {'state_id': 3, 'state_abbr': 'AR', 'year': 1996, 'population': 2510000, 'violent_crime': 13161, 'homicide': 219, 'rape_legacy': 1046, 'rape_revised': None, 'robbery': 2864, 'aggravated_assault': 9032, 'property_crime': 104790, 'burglary': 23925, 'larceny': 73010, 'motor_vehicle_theft': 7855, 'arson': None}end of loop
# {'state_id': 3, 'state_abbr': 'AR', 'year': 1996, 'population': 2510000, 'violent_crime': 13161, 'homicide': 219, 'rape_legacy': 1046, 'rape_revised': None, 'robbery': 2864, 'aggravated_assault': 9032, 'property_crime': 104790, 'burglary': 23925, 'larceny': 73010, 'motor_vehicle_theft': 7855, 'arson': None}end of loop
# {'state_id': 3, 'state_abbr': 'AR', 'year': 1996, 'population': 2510000, 'violent_crime': 13161, 'homicide': 219, 'rape_legacy': 1046, 'rape_revised': None, 'robbery': 2864, 'aggravated_assault': 9032, 'property_crime': 104790, 'burglary': 23925, 'larceny': 73010, 'motor_vehicle_theft': 7855, 'arson': None}end of loop
# {'state_id': 3, 'state_abbr': 'AR', 'year': 1996, 'population': 2510000, 'violent_crime': 13161, 'homicide': 219, 'rape_legacy': 1046, 'rape_revised': None, 'robbery': 2864, 'aggravated_assault': 9032, 'property_crime': 104790, 'burglary': 23925, 'larceny': 73010, 'motor_vehicle_theft': 7855, 'arson': None}end of loop
# {'state_id': 3, 'state_abbr': 'AR', 'year': 1996, 'population': 2510000, 'violent_crime': 13161, 'homicide': 219, 'rape_legacy': 1046, 'rape_revised': None, 'robbery': 2864, 'aggravated_assault': 9032, 'property_crime': 104790, 'burglary': 23925, 'larceny': 73010, 'motor_vehicle_theft': 7855, 'arson': None}end of loop
# {'state_id': 3, 'state_abbr': 'AR', 'year': 1996, 'population': 2510000, 'violent_crime': 13161, 'homicide': 219, 'rape_legacy': 1046, 'rape_revised': None, 'robbery': 2864, 'aggravated_assault': 9032, 'property_crime': 104790, 'burglary': 23925, 'larceny': 73010, 'motor_vehicle_theft': 7855, 'arson': None}end of loop
# {'state_id': 3, 'state_abbr': 'AR', 'year': 1996, 'population': 2510000, 'violent_crime': 13161, 'homicide': 219, 'rape_legacy': 1046, 'rape_revised': None, 'robbery': 2864, 'aggravated_assault': 9032, 'property_crime': 104790, 'burglary': 23925, 'larceny': 73010, 'motor_vehicle_theft': 7855, 'arson': None}end of loop
# {'state_id': 3, 'state_abbr': 'AR', 'year': 1996, 'population': 2510000, 'violent_crime': 13161, 'homicide': 219, 'rape_legacy': 1046, 'rape_revised': None, 'robbery': 2864, 'aggravated_assault': 9032, 'property_crime': 104790, 'burglary': 23925, 'larceny': 73010, 'motor_vehicle_theft': 7855, 'arson': None}end of loop
# {'state_id': 3, 'state_abbr': 'AR', 'year': 1996, 'population': 2510000, 'violent_crime': 13161, 'homicide': 219, 'rape_legacy': 1046, 'rape_revised': None, 'robbery': 2864, 'aggravated_assault': 9032, 'property_crime': 104790, 'burglary': 23925, 'larceny': 73010, 'motor_vehicle_theft': 7855, 'arson': None}end of loop
# {'state_id': 3, 'state_abbr': 'AR', 'year': 1996, 'population': 2510000, 'violent_crime': 13161, 'homicide': 219, 'rape_legacy': 1046, 'rape_revised': None, 'robbery': 2864, 'aggravated_assault': 9032, 'property_crime': 104790, 'burglary': 23925, 'larceny': 73010, 'motor_vehicle_theft': 7855, 'arson': None}end of loop
# {'state_id': 5, 'state_abbr': 'AZ', 'year': 1996, 'population': 4428000, 'violent_crime': 27963, 'homicide': 377, 'rape_legacy': 1381, 'rape_revised': None, 'robbery': 7429, 'aggravated_assault': 18776, 'property_crime': 284964, 'burglary': 55630, 'larceny': 188300, 'motor_vehicle_theft': 41034, 'arson': None}end of loop
# {'state_id': 5, 'state_abbr': 'AZ', 'year': 1996, 'population': 4428000, 'violent_crime': 27963, 'homicide': 377, 'rape_legacy': 1381, 'rape_revised': None, 'robbery': 7429, 'aggravated_assault': 18776, 'property_crime': 284964, 'burglary': 55630, 'larceny': 188300, 'motor_vehicle_theft': 41034, 'arson': None}end of loop
# {'state_id': 5, 'state_abbr': 'AZ', 'year': 1996, 'population': 4428000, 'violent_crime': 27963, 'homicide': 377, 'rape_legacy': 1381, 'rape_revised': None, 'robbery': 7429, 'aggravated_assault': 18776, 'property_crime': 284964, 'burglary': 55630, 'larceny': 188300, 'motor_vehicle_theft': 41034, 'arson': None}end of loop
# {'state_id': 5, 'state_abbr': 'AZ', 'year': 1996, 'population': 4428000, 'violent_crime': 27963, 'homicide': 377, 'rape_legacy': 1381, 'rape_revised': None, 'robbery': 7429, 'aggravated_assault': 18776, 'property_crime': 284964, 'burglary': 55630, 'larceny': 188300, 'motor_vehicle_theft': 41034, 'arson': None}end of loop
# {'state_id': 5, 'state_abbr': 'AZ', 'year': 1996, 'population': 4428000, 'violent_crime': 27963, 'homicide': 377, 'rape_legacy': 1381, 'rape_revised': None, 'robbery': 7429, 'aggravated_assault': 18776, 'property_crime': 284964, 'burglary': 55630, 'larceny': 188300, 'motor_vehicle_theft': 41034, 'arson': None}end of loop
# {'state_id': 5, 'state_abbr': 'AZ', 'year': 1996, 'population': 4428000, 'violent_crime': 27963, 'homicide': 377, 'rape_legacy': 1381, 'rape_revised': None, 'robbery': 7429, 'aggravated_assault': 18776, 'property_crime': 284964, 'burglary': 55630, 'larceny': 188300, 'motor_vehicle_theft': 41034, 'arson': None}end of loop
# {'state_id': 5, 'state_abbr': 'AZ', 'year': 1996, 'population': 4428000, 'violent_crime': 27963, 'homicide': 377, 'rape_legacy': 1381, 'rape_revised': None, 'robbery': 7429, 'aggravated_assault': 18776, 'property_crime': 284964, 'burglary': 55630, 'larceny': 188300, 'motor_vehicle_theft': 41034, 'arson': None}end of loop
# {'state_id': 5, 'state_abbr': 'AZ', 'year': 1996, 'population': 4428000, 'violent_crime': 27963, 'homicide': 377, 'rape_legacy': 1381, 'rape_revised': None, 'robbery': 7429, 'aggravated_assault': 18776, 'property_crime': 284964, 'burglary': 55630, 'larceny': 188300, 'motor_vehicle_theft': 41034, 'arson': None}end of loop
# {'state_id': 5, 'state_abbr': 'AZ', 'year': 1996, 'population': 4428000, 'violent_crime': 27963, 'homicide': 377, 'rape_legacy': 1381, 'rape_revised': None, 'robbery': 7429, 'aggravated_assault': 18776, 'property_crime': 284964, 'burglary': 55630, 'larceny': 188300, 'motor_vehicle_theft': 41034, 'arson': None}end of loop
# {'state_id': 5, 'state_abbr': 'AZ', 'year': 1996, 'population': 4428000, 'violent_crime': 27963, 'homicide': 377, 'rape_legacy': 1381, 'rape_revised': None, 'robbery': 7429, 'aggravated_assault': 18776, 'property_crime': 284964, 'burglary': 55630, 'larceny': 188300, 'motor_vehicle_theft': 41034, 'arson': None}end of loop
# {'state_id': 5, 'state_abbr': 'AZ', 'year': 1996, 'population': 4428000, 'violent_crime': 27963, 'homicide': 377, 'rape_legacy': 1381, 'rape_revised': None, 'robbery': 7429, 'aggravated_assault': 18776, 'property_crime': 284964, 'burglary': 55630, 'larceny': 188300, 'motor_vehicle_theft': 41034, 'arson': None}end of loop
# {'state_id': 5, 'state_abbr': 'AZ', 'year': 1996, 'population': 4428000, 'violent_crime': 27963, 'homicide': 377, 'rape_legacy': 1381, 'rape_revised': None, 'robbery': 7429, 'aggravated_assault': 18776, 'property_crime': 284964, 'burglary': 55630, 'larceny': 188300, 'motor_vehicle_theft': 41034, 'arson': None}end of loop
# {'state_id': 5, 'state_abbr': 'AZ', 'year': 1996, 'population': 4428000, 'violent_crime': 27963, 'homicide': 377, 'rape_legacy': 1381, 'rape_revised': None, 'robbery': 7429, 'aggravated_assault': 18776, 'property_crime': 284964, 'burglary': 55630, 'larceny': 188300, 'motor_vehicle_theft': 41034, 'arson': None}end of loop
# {'state_id': 5, 'state_abbr': 'AZ', 'year': 1996, 'population': 4428000, 'violent_crime': 27963, 'homicide': 377, 'rape_legacy': 1381, 'rape_revised': None, 'robbery': 7429, 'aggravated_assault': 18776, 'property_crime': 284964, 'burglary': 55630, 'larceny': 188300, 'motor_vehicle_theft': 41034, 'arson': None}end of loop
# {'state_id': 5, 'state_abbr': 'AZ', 'year': 1996, 'population': 4428000, 'violent_crime': 27963, 'homicide': 377, 'rape_legacy': 1381, 'rape_revised': None, 'robbery': 7429, 'aggravated_assault': 18776, 'property_crime': 284964, 'burglary': 55630, 'larceny': 188300, 'motor_vehicle_theft': 41034, 'arson': None}end of loop
# {'state_id': 6, 'state_abbr': 'CA', 'year': 2016, 'population': 39296476, 'violent_crime': 174796, 'homicide': 1930, 'rape_legacy': 13702, 'rape_revised': 13702, 'robbery': 54789, 'aggravated_assault': 104375, 'property_crime': 1002070, 'burglary': 188304, 'larceny': 637010, 'motor_vehicle_theft': 176756, 'arson': 7766}end of loop
# {'state_id': 6, 'state_abbr': 'CA', 'year': 2016, 'population': 39296476, 'violent_crime': 174796, 'homicide': 1930, 'rape_legacy': 13702, 'rape_revised': 13702, 'robbery': 54789, 'aggravated_assault': 104375, 'property_crime': 1002070, 'burglary': 188304, 'larceny': 637010, 'motor_vehicle_theft': 176756, 'arson': 7766}end of loop
# {'state_id': 6, 'state_abbr': 'CA', 'year': 2016, 'population': 39296476, 'violent_crime': 174796, 'homicide': 1930, 'rape_legacy': 13702, 'rape_revised': 13702, 'robbery': 54789, 'aggravated_assault': 104375, 'property_crime': 1002070, 'burglary': 188304, 'larceny': 637010, 'motor_vehicle_theft': 176756, 'arson': 7766}end of loop
# {'state_id': 6, 'state_abbr': 'CA', 'year': 2016, 'population': 39296476, 'violent_crime': 174796, 'homicide': 1930, 'rape_legacy': 13702, 'rape_revised': 13702, 'robbery': 54789, 'aggravated_assault': 104375, 'property_crime': 1002070, 'burglary': 188304, 'larceny': 637010, 'motor_vehicle_theft': 176756, 'arson': 7766}end of loop
# {'state_id': 6, 'state_abbr': 'CA', 'year': 2016, 'population': 39296476, 'violent_crime': 174796, 'homicide': 1930, 'rape_legacy': 13702, 'rape_revised': 13702, 'robbery': 54789, 'aggravated_assault': 104375, 'property_crime': 1002070, 'burglary': 188304, 'larceny': 637010, 'motor_vehicle_theft': 176756, 'arson': 7766}end of loop
# {'state_id': 6, 'state_abbr': 'CA', 'year': 2016, 'population': 39296476, 'violent_crime': 174796, 'homicide': 1930, 'rape_legacy': 13702, 'rape_revised': 13702, 'robbery': 54789, 'aggravated_assault': 104375, 'property_crime': 1002070, 'burglary': 188304, 'larceny': 637010, 'motor_vehicle_theft': 176756, 'arson': 7766}end of loop
# {'state_id': 6, 'state_abbr': 'CA', 'year': 2016, 'population': 39296476, 'violent_crime': 174796, 'homicide': 1930, 'rape_legacy': 13702, 'rape_revised': 13702, 'robbery': 54789, 'aggravated_assault': 104375, 'property_crime': 1002070, 'burglary': 188304, 'larceny': 637010, 'motor_vehicle_theft': 176756, 'arson': 7766}end of loop
# {'state_id': 6, 'state_abbr': 'CA', 'year': 2016, 'population': 39296476, 'violent_crime': 174796, 'homicide': 1930, 'rape_legacy': 13702, 'rape_revised': 13702, 'robbery': 54789, 'aggravated_assault': 104375, 'property_crime': 1002070, 'burglary': 188304, 'larceny': 637010, 'motor_vehicle_theft': 176756, 'arson': 7766}end of loop
# {'state_id': 6, 'state_abbr': 'CA', 'year': 2016, 'population': 39296476, 'violent_crime': 174796, 'homicide': 1930, 'rape_legacy': 13702, 'rape_revised': 13702, 'robbery': 54789, 'aggravated_assault': 104375, 'property_crime': 1002070, 'burglary': 188304, 'larceny': 637010, 'motor_vehicle_theft': 176756, 'arson': 7766}end of loop
# {'state_id': 6, 'state_abbr': 'CA', 'year': 2016, 'population': 39296476, 'violent_crime': 174796, 'homicide': 1930, 'rape_legacy': 13702, 'rape_revised': 13702, 'robbery': 54789, 'aggravated_assault': 104375, 'property_crime': 1002070, 'burglary': 188304, 'larceny': 637010, 'motor_vehicle_theft': 176756, 'arson': 7766}end of loop
# {'state_id': 6, 'state_abbr': 'CA', 'year': 2016, 'population': 39296476, 'violent_crime': 174796, 'homicide': 1930, 'rape_legacy': 13702, 'rape_revised': 13702, 'robbery': 54789, 'aggravated_assault': 104375, 'property_crime': 1002070, 'burglary': 188304, 'larceny': 637010, 'motor_vehicle_theft': 176756, 'arson': 7766}end of loop
# {'state_id': 6, 'state_abbr': 'CA', 'year': 2016, 'population': 39296476, 'violent_crime': 174796, 'homicide': 1930, 'rape_legacy': 13702, 'rape_revised': 13702, 'robbery': 54789, 'aggravated_assault': 104375, 'property_crime': 1002070, 'burglary': 188304, 'larceny': 637010, 'motor_vehicle_theft': 176756, 'arson': 7766}end of loop
# {'state_id': 6, 'state_abbr': 'CA', 'year': 2016, 'population': 39296476, 'violent_crime': 174796, 'homicide': 1930, 'rape_legacy': 13702, 'rape_revised': 13702, 'robbery': 54789, 'aggravated_assault': 104375, 'property_crime': 1002070, 'burglary': 188304, 'larceny': 637010, 'motor_vehicle_theft': 176756, 'arson': 7766}end of loop
# {'state_id': 6, 'state_abbr': 'CA', 'year': 2016, 'population': 39296476, 'violent_crime': 174796, 'homicide': 1930, 'rape_legacy': 13702, 'rape_revised': 13702, 'robbery': 54789, 'aggravated_assault': 104375, 'property_crime': 1002070, 'burglary': 188304, 'larceny': 637010, 'motor_vehicle_theft': 176756, 'arson': 7766}end of loop
# {'state_id': 6, 'state_abbr': 'CA', 'year': 2016, 'population': 39296476, 'violent_crime': 174796, 'homicide': 1930, 'rape_legacy': 13702, 'rape_revised': 13702, 'robbery': 54789, 'aggravated_assault': 104375, 'property_crime': 1002070, 'burglary': 188304, 'larceny': 637010, 'motor_vehicle_theft': 176756, 'arson': 7766}end of loop
# {'state_id': 7, 'state_abbr': 'CO', 'year': 2016, 'population': 5530105, 'violent_crime': 19030, 'homicide': 189, 'rape_legacy': 3555, 'rape_revised': 3635, 'robbery': 3525, 'aggravated_assault': 11681, 'property_crime': 152146, 'burglary': 23825, 'larceny': 108680, 'motor_vehicle_theft': 19641, 'arson': 940}end of loop
# {'state_id': 7, 'state_abbr': 'CO', 'year': 2016, 'population': 5530105, 'violent_crime': 19030, 'homicide': 189, 'rape_legacy': 3555, 'rape_revised': 3635, 'robbery': 3525, 'aggravated_assault': 11681, 'property_crime': 152146, 'burglary': 23825, 'larceny': 108680, 'motor_vehicle_theft': 19641, 'arson': 940}end of loop
# {'state_id': 7, 'state_abbr': 'CO', 'year': 2016, 'population': 5530105, 'violent_crime': 19030, 'homicide': 189, 'rape_legacy': 3555, 'rape_revised': 3635, 'robbery': 3525, 'aggravated_assault': 11681, 'property_crime': 152146, 'burglary': 23825, 'larceny': 108680, 'motor_vehicle_theft': 19641, 'arson': 940}end of loop
# {'state_id': 7, 'state_abbr': 'CO', 'year': 2016, 'population': 5530105, 'violent_crime': 19030, 'homicide': 189, 'rape_legacy': 3555, 'rape_revised': 3635, 'robbery': 3525, 'aggravated_assault': 11681, 'property_crime': 152146, 'burglary': 23825, 'larceny': 108680, 'motor_vehicle_theft': 19641, 'arson': 940}end of loop
# {'state_id': 7, 'state_abbr': 'CO', 'year': 2016, 'population': 5530105, 'violent_crime': 19030, 'homicide': 189, 'rape_legacy': 3555, 'rape_revised': 3635, 'robbery': 3525, 'aggravated_assault': 11681, 'property_crime': 152146, 'burglary': 23825, 'larceny': 108680, 'motor_vehicle_theft': 19641, 'arson': 940}end of loop
# {'state_id': 7, 'state_abbr': 'CO', 'year': 2016, 'population': 5530105, 'violent_crime': 19030, 'homicide': 189, 'rape_legacy': 3555, 'rape_revised': 3635, 'robbery': 3525, 'aggravated_assault': 11681, 'property_crime': 152146, 'burglary': 23825, 'larceny': 108680, 'motor_vehicle_theft': 19641, 'arson': 940}end of loop
# {'state_id': 7, 'state_abbr': 'CO', 'year': 2016, 'population': 5530105, 'violent_crime': 19030, 'homicide': 189, 'rape_legacy': 3555, 'rape_revised': 3635, 'robbery': 3525, 'aggravated_assault': 11681, 'property_crime': 152146, 'burglary': 23825, 'larceny': 108680, 'motor_vehicle_theft': 19641, 'arson': 940}end of loop
# {'state_id': 7, 'state_abbr': 'CO', 'year': 2016, 'population': 5530105, 'violent_crime': 19030, 'homicide': 189, 'rape_legacy': 3555, 'rape_revised': 3635, 'robbery': 3525, 'aggravated_assault': 11681, 'property_crime': 152146, 'burglary': 23825, 'larceny': 108680, 'motor_vehicle_theft': 19641, 'arson': 940}end of loop
# {'state_id': 7, 'state_abbr': 'CO', 'year': 2016, 'population': 5530105, 'violent_crime': 19030, 'homicide': 189, 'rape_legacy': 3555, 'rape_revised': 3635, 'robbery': 3525, 'aggravated_assault': 11681, 'property_crime': 152146, 'burglary': 23825, 'larceny': 108680, 'motor_vehicle_theft': 19641, 'arson': 940}end of loop
# {'state_id': 7, 'state_abbr': 'CO', 'year': 2016, 'population': 5530105, 'violent_crime': 19030, 'homicide': 189, 'rape_legacy': 3555, 'rape_revised': 3635, 'robbery': 3525, 'aggravated_assault': 11681, 'property_crime': 152146, 'burglary': 23825, 'larceny': 108680, 'motor_vehicle_theft': 19641, 'arson': 940}end of loop
# {'state_id': 7, 'state_abbr': 'CO', 'year': 2016, 'population': 5530105, 'violent_crime': 19030, 'homicide': 189, 'rape_legacy': 3555, 'rape_revised': 3635, 'robbery': 3525, 'aggravated_assault': 11681, 'property_crime': 152146, 'burglary': 23825, 'larceny': 108680, 'motor_vehicle_theft': 19641, 'arson': 940}end of loop
# {'state_id': 7, 'state_abbr': 'CO', 'year': 2016, 'population': 5530105, 'violent_crime': 19030, 'homicide': 189, 'rape_legacy': 3555, 'rape_revised': 3635, 'robbery': 3525, 'aggravated_assault': 11681, 'property_crime': 152146, 'burglary': 23825, 'larceny': 108680, 'motor_vehicle_theft': 19641, 'arson': 940}end of loop
# {'state_id': 7, 'state_abbr': 'CO', 'year': 2016, 'population': 5530105, 'violent_crime': 19030, 'homicide': 189, 'rape_legacy': 3555, 'rape_revised': 3635, 'robbery': 3525, 'aggravated_assault': 11681, 'property_crime': 152146, 'burglary': 23825, 'larceny': 108680, 'motor_vehicle_theft': 19641, 'arson': 940}end of loop
# {'state_id': 7, 'state_abbr': 'CO', 'year': 2016, 'population': 5530105, 'violent_crime': 19030, 'homicide': 189, 'rape_legacy': 3555, 'rape_revised': 3635, 'robbery': 3525, 'aggravated_assault': 11681, 'property_crime': 152146, 'burglary': 23825, 'larceny': 108680, 'motor_vehicle_theft': 19641, 'arson': 940}end of loop
# {'state_id': 7, 'state_abbr': 'CO', 'year': 2016, 'population': 5530105, 'violent_crime': 19030, 'homicide': 189, 'rape_legacy': 3555, 'rape_revised': 3635, 'robbery': 3525, 'aggravated_assault': 11681, 'property_crime': 152146, 'burglary': 23825, 'larceny': 108680, 'motor_vehicle_theft': 19641, 'arson': 940}end of loop
# {'state_id': 8, 'state_abbr': 'CT', 'year': 2016, 'population': 3587685, 'violent_crime': 8169, 'homicide': 79, 'rape_legacy': 763, 'rape_revised': 791, 'robbery': 2711, 'aggravated_assault': 4588, 'property_crime': 64875, 'burglary': 10107, 'larceny': 47642, 'motor_vehicle_theft': 7126, 'arson': 415}end of loop
# {'state_id': 8, 'state_abbr': 'CT', 'year': 2016, 'population': 3587685, 'violent_crime': 8169, 'homicide': 79, 'rape_legacy': 763, 'rape_revised': 791, 'robbery': 2711, 'aggravated_assault': 4588, 'property_crime': 64875, 'burglary': 10107, 'larceny': 47642, 'motor_vehicle_theft': 7126, 'arson': 415}end of loop
# {'state_id': 8, 'state_abbr': 'CT', 'year': 2016, 'population': 3587685, 'violent_crime': 8169, 'homicide': 79, 'rape_legacy': 763, 'rape_revised': 791, 'robbery': 2711, 'aggravated_assault': 4588, 'property_crime': 64875, 'burglary': 10107, 'larceny': 47642, 'motor_vehicle_theft': 7126, 'arson': 415}end of loop
# {'state_id': 8, 'state_abbr': 'CT', 'year': 2016, 'population': 3587685, 'violent_crime': 8169, 'homicide': 79, 'rape_legacy': 763, 'rape_revised': 791, 'robbery': 2711, 'aggravated_assault': 4588, 'property_crime': 64875, 'burglary': 10107, 'larceny': 47642, 'motor_vehicle_theft': 7126, 'arson': 415}end of loop
# {'state_id': 8, 'state_abbr': 'CT', 'year': 2016, 'population': 3587685, 'violent_crime': 8169, 'homicide': 79, 'rape_legacy': 763, 'rape_revised': 791, 'robbery': 2711, 'aggravated_assault': 4588, 'property_crime': 64875, 'burglary': 10107, 'larceny': 47642, 'motor_vehicle_theft': 7126, 'arson': 415}end of loop
# {'state_id': 8, 'state_abbr': 'CT', 'year': 2016, 'population': 3587685, 'violent_crime': 8169, 'homicide': 79, 'rape_legacy': 763, 'rape_revised': 791, 'robbery': 2711, 'aggravated_assault': 4588, 'property_crime': 64875, 'burglary': 10107, 'larceny': 47642, 'motor_vehicle_theft': 7126, 'arson': 415}end of loop
# {'state_id': 8, 'state_abbr': 'CT', 'year': 2016, 'population': 3587685, 'violent_crime': 8169, 'homicide': 79, 'rape_legacy': 763, 'rape_revised': 791, 'robbery': 2711, 'aggravated_assault': 4588, 'property_crime': 64875, 'burglary': 10107, 'larceny': 47642, 'motor_vehicle_theft': 7126, 'arson': 415}end of loop
# {'state_id': 8, 'state_abbr': 'CT', 'year': 2016, 'population': 3587685, 'violent_crime': 8169, 'homicide': 79, 'rape_legacy': 763, 'rape_revised': 791, 'robbery': 2711, 'aggravated_assault': 4588, 'property_crime': 64875, 'burglary': 10107, 'larceny': 47642, 'motor_vehicle_theft': 7126, 'arson': 415}end of loop
# {'state_id': 8, 'state_abbr': 'CT', 'year': 2016, 'population': 3587685, 'violent_crime': 8169, 'homicide': 79, 'rape_legacy': 763, 'rape_revised': 791, 'robbery': 2711, 'aggravated_assault': 4588, 'property_crime': 64875, 'burglary': 10107, 'larceny': 47642, 'motor_vehicle_theft': 7126, 'arson': 415}end of loop
# {'state_id': 8, 'state_abbr': 'CT', 'year': 2016, 'population': 3587685, 'violent_crime': 8169, 'homicide': 79, 'rape_legacy': 763, 'rape_revised': 791, 'robbery': 2711, 'aggravated_assault': 4588, 'property_crime': 64875, 'burglary': 10107, 'larceny': 47642, 'motor_vehicle_theft': 7126, 'arson': 415}end of loop
# {'state_id': 8, 'state_abbr': 'CT', 'year': 2016, 'population': 3587685, 'violent_crime': 8169, 'homicide': 79, 'rape_legacy': 763, 'rape_revised': 791, 'robbery': 2711, 'aggravated_assault': 4588, 'property_crime': 64875, 'burglary': 10107, 'larceny': 47642, 'motor_vehicle_theft': 7126, 'arson': 415}end of loop
# {'state_id': 8, 'state_abbr': 'CT', 'year': 2016, 'population': 3587685, 'violent_crime': 8169, 'homicide': 79, 'rape_legacy': 763, 'rape_revised': 791, 'robbery': 2711, 'aggravated_assault': 4588, 'property_crime': 64875, 'burglary': 10107, 'larceny': 47642, 'motor_vehicle_theft': 7126, 'arson': 415}end of loop
# {'state_id': 8, 'state_abbr': 'CT', 'year': 2016, 'population': 3587685, 'violent_crime': 8169, 'homicide': 79, 'rape_legacy': 763, 'rape_revised': 791, 'robbery': 2711, 'aggravated_assault': 4588, 'property_crime': 64875, 'burglary': 10107, 'larceny': 47642, 'motor_vehicle_theft': 7126, 'arson': 415}end of loop
# {'state_id': 8, 'state_abbr': 'CT', 'year': 2016, 'population': 3587685, 'violent_crime': 8169, 'homicide': 79, 'rape_legacy': 763, 'rape_revised': 791, 'robbery': 2711, 'aggravated_assault': 4588, 'property_crime': 64875, 'burglary': 10107, 'larceny': 47642, 'motor_vehicle_theft': 7126, 'arson': 415}end of loop
# {'state_id': 8, 'state_abbr': 'CT', 'year': 2016, 'population': 3587685, 'violent_crime': 8169, 'homicide': 79, 'rape_legacy': 763, 'rape_revised': 791, 'robbery': 2711, 'aggravated_assault': 4588, 'property_crime': 64875, 'burglary': 10107, 'larceny': 47642, 'motor_vehicle_theft': 7126, 'arson': 415}end of loop
# {'state_id': 11, 'state_abbr': 'DE', 'year': 2016, 'population': 952698, 'violent_crime': 4859, 'homicide': 58, 'rape_legacy': 308, 'rape_revised': 311, 'robbery': 1359, 'aggravated_assault': 3131, 'property_crime': 26370, 'burglary': 5028, 'larceny': 19812, 'motor_vehicle_theft': 1530, 'arson': 181}end of loop
# {'state_id': 11, 'state_abbr': 'DE', 'year': 2016, 'population': 952698, 'violent_crime': 4859, 'homicide': 58, 'rape_legacy': 308, 'rape_revised': 311, 'robbery': 1359, 'aggravated_assault': 3131, 'property_crime': 26370, 'burglary': 5028, 'larceny': 19812, 'motor_vehicle_theft': 1530, 'arson': 181}end of loop
# {'state_id': 11, 'state_abbr': 'DE', 'year': 2016, 'population': 952698, 'violent_crime': 4859, 'homicide': 58, 'rape_legacy': 308, 'rape_revised': 311, 'robbery': 1359, 'aggravated_assault': 3131, 'property_crime': 26370, 'burglary': 5028, 'larceny': 19812, 'motor_vehicle_theft': 1530, 'arson': 181}end of loop
# {'state_id': 11, 'state_abbr': 'DE', 'year': 2016, 'population': 952698, 'violent_crime': 4859, 'homicide': 58, 'rape_legacy': 308, 'rape_revised': 311, 'robbery': 1359, 'aggravated_assault': 3131, 'property_crime': 26370, 'burglary': 5028, 'larceny': 19812, 'motor_vehicle_theft': 1530, 'arson': 181}end of loop
# {'state_id': 11, 'state_abbr': 'DE', 'year': 2016, 'population': 952698, 'violent_crime': 4859, 'homicide': 58, 'rape_legacy': 308, 'rape_revised': 311, 'robbery': 1359, 'aggravated_assault': 3131, 'property_crime': 26370, 'burglary': 5028, 'larceny': 19812, 'motor_vehicle_theft': 1530, 'arson': 181}end of loop
# {'state_id': 11, 'state_abbr': 'DE', 'year': 2016, 'population': 952698, 'violent_crime': 4859, 'homicide': 58, 'rape_legacy': 308, 'rape_revised': 311, 'robbery': 1359, 'aggravated_assault': 3131, 'property_crime': 26370, 'burglary': 5028, 'larceny': 19812, 'motor_vehicle_theft': 1530, 'arson': 181}end of loop
# {'state_id': 11, 'state_abbr': 'DE', 'year': 2016, 'population': 952698, 'violent_crime': 4859, 'homicide': 58, 'rape_legacy': 308, 'rape_revised': 311, 'robbery': 1359, 'aggravated_assault': 3131, 'property_crime': 26370, 'burglary': 5028, 'larceny': 19812, 'motor_vehicle_theft': 1530, 'arson': 181}end of loop
# {'state_id': 11, 'state_abbr': 'DE', 'year': 2016, 'population': 952698, 'violent_crime': 4859, 'homicide': 58, 'rape_legacy': 308, 'rape_revised': 311, 'robbery': 1359, 'aggravated_assault': 3131, 'property_crime': 26370, 'burglary': 5028, 'larceny': 19812, 'motor_vehicle_theft': 1530, 'arson': 181}end of loop
# {'state_id': 11, 'state_abbr': 'DE', 'year': 2016, 'population': 952698, 'violent_crime': 4859, 'homicide': 58, 'rape_legacy': 308, 'rape_revised': 311, 'robbery': 1359, 'aggravated_assault': 3131, 'property_crime': 26370, 'burglary': 5028, 'larceny': 19812, 'motor_vehicle_theft': 1530, 'arson': 181}end of loop
# {'state_id': 11, 'state_abbr': 'DE', 'year': 2016, 'population': 952698, 'violent_crime': 4859, 'homicide': 58, 'rape_legacy': 308, 'rape_revised': 311, 'robbery': 1359, 'aggravated_assault': 3131, 'property_crime': 26370, 'burglary': 5028, 'larceny': 19812, 'motor_vehicle_theft': 1530, 'arson': 181}end of loop
# {'state_id': 11, 'state_abbr': 'DE', 'year': 2016, 'population': 952698, 'violent_crime': 4859, 'homicide': 58, 'rape_legacy': 308, 'rape_revised': 311, 'robbery': 1359, 'aggravated_assault': 3131, 'property_crime': 26370, 'burglary': 5028, 'larceny': 19812, 'motor_vehicle_theft': 1530, 'arson': 181}end of loop
# {'state_id': 11, 'state_abbr': 'DE', 'year': 2016, 'population': 952698, 'violent_crime': 4859, 'homicide': 58, 'rape_legacy': 308, 'rape_revised': 311, 'robbery': 1359, 'aggravated_assault': 3131, 'property_crime': 26370, 'burglary': 5028, 'larceny': 19812, 'motor_vehicle_theft': 1530, 'arson': 181}end of loop
# {'state_id': 11, 'state_abbr': 'DE', 'year': 2016, 'population': 952698, 'violent_crime': 4859, 'homicide': 58, 'rape_legacy': 308, 'rape_revised': 311, 'robbery': 1359, 'aggravated_assault': 3131, 'property_crime': 26370, 'burglary': 5028, 'larceny': 19812, 'motor_vehicle_theft': 1530, 'arson': 181}end of loop
# {'state_id': 11, 'state_abbr': 'DE', 'year': 2016, 'population': 952698, 'violent_crime': 4859, 'homicide': 58, 'rape_legacy': 308, 'rape_revised': 311, 'robbery': 1359, 'aggravated_assault': 3131, 'property_crime': 26370, 'burglary': 5028, 'larceny': 19812, 'motor_vehicle_theft': 1530, 'arson': 181}end of loop
# {'state_id': 11, 'state_abbr': 'DE', 'year': 2016, 'population': 952698, 'violent_crime': 4859, 'homicide': 58, 'rape_legacy': 308, 'rape_revised': 311, 'robbery': 1359, 'aggravated_assault': 3131, 'property_crime': 26370, 'burglary': 5028, 'larceny': 19812, 'motor_vehicle_theft': 1530, 'arson': 181}end of loop
# {'state_id': 12, 'state_abbr': 'FL', 'year': 2016, 'population': 20656589, 'violent_crime': 88700, 'homicide': 1111, 'rape_legacy': 7598, 'rape_revised': 7598, 'robbery': 20175, 'aggravated_assault': 59816, 'property_crime': 553812, 'burglary': 100325, 'larceny': 410352, 'motor_vehicle_theft': 43135, 'arson': 1470}end of loop
# {'state_id': 12, 'state_abbr': 'FL', 'year': 2016, 'population': 20656589, 'violent_crime': 88700, 'homicide': 1111, 'rape_legacy': 7598, 'rape_revised': 7598, 'robbery': 20175, 'aggravated_assault': 59816, 'property_crime': 553812, 'burglary': 100325, 'larceny': 410352, 'motor_vehicle_theft': 43135, 'arson': 1470}end of loop
# {'state_id': 12, 'state_abbr': 'FL', 'year': 2016, 'population': 20656589, 'violent_crime': 88700, 'homicide': 1111, 'rape_legacy': 7598, 'rape_revised': 7598, 'robbery': 20175, 'aggravated_assault': 59816, 'property_crime': 553812, 'burglary': 100325, 'larceny': 410352, 'motor_vehicle_theft': 43135, 'arson': 1470}end of loop
# {'state_id': 12, 'state_abbr': 'FL', 'year': 2016, 'population': 20656589, 'violent_crime': 88700, 'homicide': 1111, 'rape_legacy': 7598, 'rape_revised': 7598, 'robbery': 20175, 'aggravated_assault': 59816, 'property_crime': 553812, 'burglary': 100325, 'larceny': 410352, 'motor_vehicle_theft': 43135, 'arson': 1470}end of loop
# {'state_id': 12, 'state_abbr': 'FL', 'year': 2016, 'population': 20656589, 'violent_crime': 88700, 'homicide': 1111, 'rape_legacy': 7598, 'rape_revised': 7598, 'robbery': 20175, 'aggravated_assault': 59816, 'property_crime': 553812, 'burglary': 100325, 'larceny': 410352, 'motor_vehicle_theft': 43135, 'arson': 1470}end of loop
# {'state_id': 12, 'state_abbr': 'FL', 'year': 2016, 'population': 20656589, 'violent_crime': 88700, 'homicide': 1111, 'rape_legacy': 7598, 'rape_revised': 7598, 'robbery': 20175, 'aggravated_assault': 59816, 'property_crime': 553812, 'burglary': 100325, 'larceny': 410352, 'motor_vehicle_theft': 43135, 'arson': 1470}end of loop
# {'state_id': 12, 'state_abbr': 'FL', 'year': 2016, 'population': 20656589, 'violent_crime': 88700, 'homicide': 1111, 'rape_legacy': 7598, 'rape_revised': 7598, 'robbery': 20175, 'aggravated_assault': 59816, 'property_crime': 553812, 'burglary': 100325, 'larceny': 410352, 'motor_vehicle_theft': 43135, 'arson': 1470}end of loop
# {'state_id': 12, 'state_abbr': 'FL', 'year': 2016, 'population': 20656589, 'violent_crime': 88700, 'homicide': 1111, 'rape_legacy': 7598, 'rape_revised': 7598, 'robbery': 20175, 'aggravated_assault': 59816, 'property_crime': 553812, 'burglary': 100325, 'larceny': 410352, 'motor_vehicle_theft': 43135, 'arson': 1470}end of loop
# {'state_id': 12, 'state_abbr': 'FL', 'year': 2016, 'population': 20656589, 'violent_crime': 88700, 'homicide': 1111, 'rape_legacy': 7598, 'rape_revised': 7598, 'robbery': 20175, 'aggravated_assault': 59816, 'property_crime': 553812, 'burglary': 100325, 'larceny': 410352, 'motor_vehicle_theft': 43135, 'arson': 1470}end of loop
# {'state_id': 12, 'state_abbr': 'FL', 'year': 2016, 'population': 20656589, 'violent_crime': 88700, 'homicide': 1111, 'rape_legacy': 7598, 'rape_revised': 7598, 'robbery': 20175, 'aggravated_assault': 59816, 'property_crime': 553812, 'burglary': 100325, 'larceny': 410352, 'motor_vehicle_theft': 43135, 'arson': 1470}end of loop
# {'state_id': 12, 'state_abbr': 'FL', 'year': 2016, 'population': 20656589, 'violent_crime': 88700, 'homicide': 1111, 'rape_legacy': 7598, 'rape_revised': 7598, 'robbery': 20175, 'aggravated_assault': 59816, 'property_crime': 553812, 'burglary': 100325, 'larceny': 410352, 'motor_vehicle_theft': 43135, 'arson': 1470}end of loop
# {'state_id': 12, 'state_abbr': 'FL', 'year': 2016, 'population': 20656589, 'violent_crime': 88700, 'homicide': 1111, 'rape_legacy': 7598, 'rape_revised': 7598, 'robbery': 20175, 'aggravated_assault': 59816, 'property_crime': 553812, 'burglary': 100325, 'larceny': 410352, 'motor_vehicle_theft': 43135, 'arson': 1470}end of loop
# {'state_id': 12, 'state_abbr': 'FL', 'year': 2016, 'population': 20656589, 'violent_crime': 88700, 'homicide': 1111, 'rape_legacy': 7598, 'rape_revised': 7598, 'robbery': 20175, 'aggravated_assault': 59816, 'property_crime': 553812, 'burglary': 100325, 'larceny': 410352, 'motor_vehicle_theft': 43135, 'arson': 1470}end of loop
# {'state_id': 12, 'state_abbr': 'FL', 'year': 2016, 'population': 20656589, 'violent_crime': 88700, 'homicide': 1111, 'rape_legacy': 7598, 'rape_revised': 7598, 'robbery': 20175, 'aggravated_assault': 59816, 'property_crime': 553812, 'burglary': 100325, 'larceny': 410352, 'motor_vehicle_theft': 43135, 'arson': 1470}end of loop
# {'state_id': 12, 'state_abbr': 'FL', 'year': 2016, 'population': 20656589, 'violent_crime': 88700, 'homicide': 1111, 'rape_legacy': 7598, 'rape_revised': 7598, 'robbery': 20175, 'aggravated_assault': 59816, 'property_crime': 553812, 'burglary': 100325, 'larceny': 410352, 'motor_vehicle_theft': 43135, 'arson': 1470}end of loop
# {'state_id': 13, 'state_abbr': 'GA', 'year': 2016, 'population': 10313620, 'violent_crime': 40268, 'homicide': 682, 'rape_legacy': 3509, 'rape_revised': 3381, 'robbery': 12114, 'aggravated_assault': 24091, 'property_crime': 307305, 'burglary': 62715, 'larceny': 218127, 'motor_vehicle_theft': 26463, 'arson': 1086}end of loop
# {'state_id': 13, 'state_abbr': 'GA', 'year': 2016, 'population': 10313620, 'violent_crime': 40268, 'homicide': 682, 'rape_legacy': 3509, 'rape_revised': 3381, 'robbery': 12114, 'aggravated_assault': 24091, 'property_crime': 307305, 'burglary': 62715, 'larceny': 218127, 'motor_vehicle_theft': 26463, 'arson': 1086}end of loop
# {'state_id': 13, 'state_abbr': 'GA', 'year': 2016, 'population': 10313620, 'violent_crime': 40268, 'homicide': 682, 'rape_legacy': 3509, 'rape_revised': 3381, 'robbery': 12114, 'aggravated_assault': 24091, 'property_crime': 307305, 'burglary': 62715, 'larceny': 218127, 'motor_vehicle_theft': 26463, 'arson': 1086}end of loop
# {'state_id': 13, 'state_abbr': 'GA', 'year': 2016, 'population': 10313620, 'violent_crime': 40268, 'homicide': 682, 'rape_legacy': 3509, 'rape_revised': 3381, 'robbery': 12114, 'aggravated_assault': 24091, 'property_crime': 307305, 'burglary': 62715, 'larceny': 218127, 'motor_vehicle_theft': 26463, 'arson': 1086}end of loop
# {'state_id': 13, 'state_abbr': 'GA', 'year': 2016, 'population': 10313620, 'violent_crime': 40268, 'homicide': 682, 'rape_legacy': 3509, 'rape_revised': 3381, 'robbery': 12114, 'aggravated_assault': 24091, 'property_crime': 307305, 'burglary': 62715, 'larceny': 218127, 'motor_vehicle_theft': 26463, 'arson': 1086}end of loop
# {'state_id': 13, 'state_abbr': 'GA', 'year': 2016, 'population': 10313620, 'violent_crime': 40268, 'homicide': 682, 'rape_legacy': 3509, 'rape_revised': 3381, 'robbery': 12114, 'aggravated_assault': 24091, 'property_crime': 307305, 'burglary': 62715, 'larceny': 218127, 'motor_vehicle_theft': 26463, 'arson': 1086}end of loop
# {'state_id': 13, 'state_abbr': 'GA', 'year': 2016, 'population': 10313620, 'violent_crime': 40268, 'homicide': 682, 'rape_legacy': 3509, 'rape_revised': 3381, 'robbery': 12114, 'aggravated_assault': 24091, 'property_crime': 307305, 'burglary': 62715, 'larceny': 218127, 'motor_vehicle_theft': 26463, 'arson': 1086}end of loop
# {'state_id': 13, 'state_abbr': 'GA', 'year': 2016, 'population': 10313620, 'violent_crime': 40268, 'homicide': 682, 'rape_legacy': 3509, 'rape_revised': 3381, 'robbery': 12114, 'aggravated_assault': 24091, 'property_crime': 307305, 'burglary': 62715, 'larceny': 218127, 'motor_vehicle_theft': 26463, 'arson': 1086}end of loop
# {'state_id': 13, 'state_abbr': 'GA', 'year': 2016, 'population': 10313620, 'violent_crime': 40268, 'homicide': 682, 'rape_legacy': 3509, 'rape_revised': 3381, 'robbery': 12114, 'aggravated_assault': 24091, 'property_crime': 307305, 'burglary': 62715, 'larceny': 218127, 'motor_vehicle_theft': 26463, 'arson': 1086}end of loop
# {'state_id': 13, 'state_abbr': 'GA', 'year': 2016, 'population': 10313620, 'violent_crime': 40268, 'homicide': 682, 'rape_legacy': 3509, 'rape_revised': 3381, 'robbery': 12114, 'aggravated_assault': 24091, 'property_crime': 307305, 'burglary': 62715, 'larceny': 218127, 'motor_vehicle_theft': 26463, 'arson': 1086}end of loop
# {'state_id': 13, 'state_abbr': 'GA', 'year': 2016, 'population': 10313620, 'violent_crime': 40268, 'homicide': 682, 'rape_legacy': 3509, 'rape_revised': 3381, 'robbery': 12114, 'aggravated_assault': 24091, 'property_crime': 307305, 'burglary': 62715, 'larceny': 218127, 'motor_vehicle_theft': 26463, 'arson': 1086}end of loop
# {'state_id': 13, 'state_abbr': 'GA', 'year': 2016, 'population': 10313620, 'violent_crime': 40268, 'homicide': 682, 'rape_legacy': 3509, 'rape_revised': 3381, 'robbery': 12114, 'aggravated_assault': 24091, 'property_crime': 307305, 'burglary': 62715, 'larceny': 218127, 'motor_vehicle_theft': 26463, 'arson': 1086}end of loop
# {'state_id': 13, 'state_abbr': 'GA', 'year': 2016, 'population': 10313620, 'violent_crime': 40268, 'homicide': 682, 'rape_legacy': 3509, 'rape_revised': 3381, 'robbery': 12114, 'aggravated_assault': 24091, 'property_crime': 307305, 'burglary': 62715, 'larceny': 218127, 'motor_vehicle_theft': 26463, 'arson': 1086}end of loop
# {'state_id': 13, 'state_abbr': 'GA', 'year': 2016, 'population': 10313620, 'violent_crime': 40268, 'homicide': 682, 'rape_legacy': 3509, 'rape_revised': 3381, 'robbery': 12114, 'aggravated_assault': 24091, 'property_crime': 307305, 'burglary': 62715, 'larceny': 218127, 'motor_vehicle_theft': 26463, 'arson': 1086}end of loop
# ...
# {'state_id': 27, 'state_abbr': 'MN', 'year': 2016, 'population': 5525050, 'violent_crime': 13365, 'homicide': 101, 'rape_legacy': 2348, 'rape_revised': 2349, 'robbery': 3730, 'aggravated_assault': 7185, 'property_crime': 117723, 'burglary': 18582, 'larceny': 90421, 'motor_vehicle_theft': 8720, 'arson': 497}end of loop
# {'state_id': 27, 'state_abbr': 'MN', 'year': 2016, 'population': 5525050, 'violent_crime': 13365, 'homicide': 101, 'rape_legacy': 2348, 'rape_revised': 2349, 'robbery': 3730, 'aggravated_assault': 7185, 'property_crime': 117723, 'burglary': 18582, 'larceny': 90421, 'motor_vehicle_theft': 8720, 'arson': 497}end of loop
# {'state_id': 27, 'state_abbr': 'MN', 'year': 2016, 'population': 5525050, 'violent_crime': 13365, 'homicide': 101, 'rape_legacy': 2348, 'rape_revised': 2349, 'robbery': 3730, 'aggravated_assault': 7185, 'property_crime': 117723, 'burglary': 18582, 'larceny': 90421, 'motor_vehicle_theft': 8720, 'arson': 497}end of loop
# {'state_id': 28, 'state_abbr': 'MO', 'year': 2016, 'population': 6091176, 'violent_crime': 31720, 'homicide': 538, 'rape_legacy': 2554, 'rape_revised': 2557, 'robbery': 6576, 'aggravated_assault': 22049, 'property_crime': 170661, 'burglary': 31716, 'larceny': 120649, 'motor_vehicle_theft': 18296, 'arson': 1349}end of loop
# {'state_id': 28, 'state_abbr': 'MO', 'year': 2016, 'population': 6091176, 'violent_crime': 31720, 'homicide': 538, 'rape_legacy': 2554, 'rape_revised': 2557, 'robbery': 6576, 'aggravated_assault': 22049, 'property_crime': 170661, 'burglary': 31716, 'larceny': 120649, 'motor_vehicle_theft': 18296, 'arson': 1349}end of loop
# {'state_id': 28, 'state_abbr': 'MO', 'year': 2016, 'population': 6091176, 'violent_crime': 31720, 'homicide': 538, 'rape_legacy': 2554, 'rape_revised': 2557, 'robbery': 6576, 'aggravated_assault': 22049, 'property_crime': 170661, 'burglary': 31716, 'larceny': 120649, 'motor_vehicle_theft': 18296, 'arson': 1349}end of loop
# {'state_id': 28, 'state_abbr': 'MO', 'year': 2016, 'population': 6091176, 'violent_crime': 31720, 'homicide': 538, 'rape_legacy': 2554, 'rape_revised': 2557, 'robbery': 6576, 'aggravated_assault': 22049, 'property_crime': 170661, 'burglary': 31716, 'larceny': 120649, 'motor_vehicle_theft': 18296, 'arson': 1349}end of loop
# {'state_id': 28, 'state_abbr': 'MO', 'year': 2016, 'population': 6091176, 'violent_crime': 31720, 'homicide': 538, 'rape_legacy': 2554, 'rape_revised': 2557, 'robbery': 6576, 'aggravated_assault': 22049, 'property_crime': 170661, 'burglary': 31716, 'larceny': 120649, 'motor_vehicle_theft': 18296, 'arson': 1349}end of loop
# {'state_id': 28, 'state_abbr': 'MO', 'year': 2016, 'population': 6091176, 'violent_crime': 31720, 'homicide': 538, 'rape_legacy': 2554, 'rape_revised': 2557, 'robbery': 6576, 'aggravated_assault': 22049, 'property_crime': 170661, 'burglary': 31716, 'larceny': 120649, 'motor_vehicle_theft': 18296, 'arson': 1349}end of loop
# {'state_id': 28, 'state_abbr': 'MO', 'year': 2016, 'population': 6091176, 'violent_crime': 31720, 'homicide': 538, 'rape_legacy': 2554, 'rape_revised': 2557, 'robbery': 6576, 'aggravated_assault': 22049, 'property_crime': 170661, 'burglary': 31716, 'larceny': 120649, 'motor_vehicle_theft': 18296, 'arson': 1349}end of loop
# {'state_id': 28, 'state_abbr': 'MO', 'year': 2016, 'population': 6091176, 'violent_crime': 31720, 'homicide': 538, 'rape_legacy': 2554, 'rape_revised': 2557, 'robbery': 6576, 'aggravated_assault': 22049, 'property_crime': 170661, 'burglary': 31716, 'larceny': 120649, 'motor_vehicle_theft': 18296, 'arson': 1349}end of loop
# {'state_id': 28, 'state_abbr': 'MO', 'year': 2016, 'population': 6091176, 'violent_crime': 31720, 'homicide': 538, 'rape_legacy': 2554, 'rape_revised': 2557, 'robbery': 6576, 'aggravated_assault': 22049, 'property_crime': 170661, 'burglary': 31716, 'larceny': 120649, 'motor_vehicle_theft': 18296, 'arson': 1349}end of loop
# {'state_id': 28, 'state_abbr': 'MO', 'year': 2016, 'population': 6091176, 'violent_crime': 31720, 'homicide': 538, 'rape_legacy': 2554, 'rape_revised': 2557, 'robbery': 6576, 'aggravated_assault': 22049, 'property_crime': 170661, 'burglary': 31716, 'larceny': 120649, 'motor_vehicle_theft': 18296, 'arson': 1349}end of loop
# {'state_id': 28, 'state_abbr': 'MO', 'year': 2016, 'population': 6091176, 'violent_crime': 31720, 'homicide': 538, 'rape_legacy': 2554, 'rape_revised': 2557, 'robbery': 6576, 'aggravated_assault': 22049, 'property_crime': 170661, 'burglary': 31716, 'larceny': 120649, 'motor_vehicle_theft': 18296, 'arson': 1349}end of loop
# {'state_id': 28, 'state_abbr': 'MO', 'year': 2016, 'population': 6091176, 'violent_crime': 31720, 'homicide': 538, 'rape_legacy': 2554, 'rape_revised': 2557, 'robbery': 6576, 'aggravated_assault': 22049, 'property_crime': 170661, 'burglary': 31716, 'larceny': 120649, 'motor_vehicle_theft': 18296, 'arson': 1349}end of loop
# {'state_id': 28, 'state_abbr': 'MO', 'year': 2016, 'population': 6091176, 'violent_crime': 31720, 'homicide': 538, 'rape_legacy': 2554, 'rape_revised': 2557, 'robbery': 6576, 'aggravated_assault': 22049, 'property_crime': 170661, 'burglary': 31716, 'larceny': 120649, 'motor_vehicle_theft': 18296, 'arson': 1349}end of loop
# {'state_id': 28, 'state_abbr': 'MO', 'year': 2016, 'population': 6091176, 'violent_crime': 31720, 'homicide': 538, 'rape_legacy': 2554, 'rape_revised': 2557, 'robbery': 6576, 'aggravated_assault': 22049, 'property_crime': 170661, 'burglary': 31716, 'larceny': 120649, 'motor_vehicle_theft': 18296, 'arson': 1349}end of loop
# {'state_id': 28, 'state_abbr': 'MO', 'year': 2016, 'population': 6091176, 'violent_crime': 31720, 'homicide': 538, 'rape_legacy': 2554, 'rape_revised': 2557, 'robbery': 6576, 'aggravated_assault': 22049, 'property_crime': 170661, 'burglary': 31716, 'larceny': 120649, 'motor_vehicle_theft': 18296, 'arson': 1349}end of loop
# {'state_id': 29, 'state_abbr': 'MS', 'year': 2016, 'population': 2985415, 'violent_crime': 8411, 'homicide': 237, 'rape_legacy': 1277, 'rape_revised': 1282, 'robbery': 2433, 'aggravated_assault': 4459, 'property_crime': 82521, 'burglary': 23489, 'larceny': 54725, 'motor_vehicle_theft': 4307, 'arson': 327}end of loop
# {'state_id': 29, 'state_abbr': 'MS', 'year': 2016, 'population': 2985415, 'violent_crime': 8411, 'homicide': 237, 'rape_legacy': 1277, 'rape_revised': 1282, 'robbery': 2433, 'aggravated_assault': 4459, 'property_crime': 82521, 'burglary': 23489, 'larceny': 54725, 'motor_vehicle_theft': 4307, 'arson': 327}end of loop
# {'state_id': 29, 'state_abbr': 'MS', 'year': 2016, 'population': 2985415, 'violent_crime': 8411, 'homicide': 237, 'rape_legacy': 1277, 'rape_revised': 1282, 'robbery': 2433, 'aggravated_assault': 4459, 'property_crime': 82521, 'burglary': 23489, 'larceny': 54725, 'motor_vehicle_theft': 4307, 'arson': 327}end of loop
# {'state_id': 29, 'state_abbr': 'MS', 'year': 2016, 'population': 2985415, 'violent_crime': 8411, 'homicide': 237, 'rape_legacy': 1277, 'rape_revised': 1282, 'robbery': 2433, 'aggravated_assault': 4459, 'property_crime': 82521, 'burglary': 23489, 'larceny': 54725, 'motor_vehicle_theft': 4307, 'arson': 327}end of loop
# {'state_id': 29, 'state_abbr': 'MS', 'year': 2016, 'population': 2985415, 'violent_crime': 8411, 'homicide': 237, 'rape_legacy': 1277, 'rape_revised': 1282, 'robbery': 2433, 'aggravated_assault': 4459, 'property_crime': 82521, 'burglary': 23489, 'larceny': 54725, 'motor_vehicle_theft': 4307, 'arson': 327}end of loop
# {'state_id': 29, 'state_abbr': 'MS', 'year': 2016, 'population': 2985415, 'violent_crime': 8411, 'homicide': 237, 'rape_legacy': 1277, 'rape_revised': 1282, 'robbery': 2433, 'aggravated_assault': 4459, 'property_crime': 82521, 'burglary': 23489, 'larceny': 54725, 'motor_vehicle_theft': 4307, 'arson': 327}end of loop
# {'state_id': 29, 'state_abbr': 'MS', 'year': 2016, 'population': 2985415, 'violent_crime': 8411, 'homicide': 237, 'rape_legacy': 1277, 'rape_revised': 1282, 'robbery': 2433, 'aggravated_assault': 4459, 'property_crime': 82521, 'burglary': 23489, 'larceny': 54725, 'motor_vehicle_theft': 4307, 'arson': 327}end of loop
# {'state_id': 29, 'state_abbr': 'MS', 'year': 2016, 'population': 2985415, 'violent_crime': 8411, 'homicide': 237, 'rape_legacy': 1277, 'rape_revised': 1282, 'robbery': 2433, 'aggravated_assault': 4459, 'property_crime': 82521, 'burglary': 23489, 'larceny': 54725, 'motor_vehicle_theft': 4307, 'arson': 327}end of loop
# {'state_id': 29, 'state_abbr': 'MS', 'year': 2016, 'population': 2985415, 'violent_crime': 8411, 'homicide': 237, 'rape_legacy': 1277, 'rape_revised': 1282, 'robbery': 2433, 'aggravated_assault': 4459, 'property_crime': 82521, 'burglary': 23489, 'larceny': 54725, 'motor_vehicle_theft': 4307, 'arson': 327}end of loop
# {'state_id': 29, 'state_abbr': 'MS', 'year': 2016, 'population': 2985415, 'violent_crime': 8411, 'homicide': 237, 'rape_legacy': 1277, 'rape_revised': 1282, 'robbery': 2433, 'aggravated_assault': 4459, 'property_crime': 82521, 'burglary': 23489, 'larceny': 54725, 'motor_vehicle_theft': 4307, 'arson': 327}end of loop
# {'state_id': 29, 'state_abbr': 'MS', 'year': 2016, 'population': 2985415, 'violent_crime': 8411, 'homicide': 237, 'rape_legacy': 1277, 'rape_revised': 1282, 'robbery': 2433, 'aggravated_assault': 4459, 'property_crime': 82521, 'burglary': 23489, 'larceny': 54725, 'motor_vehicle_theft': 4307, 'arson': 327}end of loop
# {'state_id': 29, 'state_abbr': 'MS', 'year': 2016, 'population': 2985415, 'violent_crime': 8411, 'homicide': 237, 'rape_legacy': 1277, 'rape_revised': 1282, 'robbery': 2433, 'aggravated_assault': 4459, 'property_crime': 82521, 'burglary': 23489, 'larceny': 54725, 'motor_vehicle_theft': 4307, 'arson': 327}end of loop
# {'state_id': 29, 'state_abbr': 'MS', 'year': 2016, 'population': 2985415, 'violent_crime': 8411, 'homicide': 237, 'rape_legacy': 1277, 'rape_revised': 1282, 'robbery': 2433, 'aggravated_assault': 4459, 'property_crime': 82521, 'burglary': 23489, 'larceny': 54725, 'motor_vehicle_theft': 4307, 'arson': 327}end of loop
# {'state_id': 29, 'state_abbr': 'MS', 'year': 2016, 'population': 2985415, 'violent_crime': 8411, 'homicide': 237, 'rape_legacy': 1277, 'rape_revised': 1282, 'robbery': 2433, 'aggravated_assault': 4459, 'property_crime': 82521, 'burglary': 23489, 'larceny': 54725, 'motor_vehicle_theft': 4307, 'arson': 327}end of loop
# {'state_id': 29, 'state_abbr': 'MS', 'year': 2016, 'population': 2985415, 'violent_crime': 8411, 'homicide': 237, 'rape_legacy': 1277, 'rape_revised': 1282, 'robbery': 2433, 'aggravated_assault': 4459, 'property_crime': 82521, 'burglary': 23489, 'larceny': 54725, 'motor_vehicle_theft': 4307, 'arson': 327}end of loop
# {'state_id': 30, 'state_abbr': 'MT', 'year': 2016, 'population': 1038656, 'violent_crime': 3886, 'homicide': 37, 'rape_legacy': 578, 'rape_revised': 598, 'robbery': 268, 'aggravated_assault': 2983, 'property_crime': 28156, 'burglary': 3966, 'larceny': 21427, 'motor_vehicle_theft': 2763, 'arson': 180}end of loop
# {'state_id': 30, 'state_abbr': 'MT', 'year': 2016, 'population': 1038656, 'violent_crime': 3886, 'homicide': 37, 'rape_legacy': 578, 'rape_revised': 598, 'robbery': 268, 'aggravated_assault': 2983, 'property_crime': 28156, 'burglary': 3966, 'larceny': 21427, 'motor_vehicle_theft': 2763, 'arson': 180}end of loop
# {'state_id': 30, 'state_abbr': 'MT', 'year': 2016, 'population': 1038656, 'violent_crime': 3886, 'homicide': 37, 'rape_legacy': 578, 'rape_revised': 598, 'robbery': 268, 'aggravated_assault': 2983, 'property_crime': 28156, 'burglary': 3966, 'larceny': 21427, 'motor_vehicle_theft': 2763, 'arson': 180}end of loop
# {'state_id': 30, 'state_abbr': 'MT', 'year': 2016, 'population': 1038656, 'violent_crime': 3886, 'homicide': 37, 'rape_legacy': 578, 'rape_revised': 598, 'robbery': 268, 'aggravated_assault': 2983, 'property_crime': 28156, 'burglary': 3966, 'larceny': 21427, 'motor_vehicle_theft': 2763, 'arson': 180}end of loop
# {'state_id': 30, 'state_abbr': 'MT', 'year': 2016, 'population': 1038656, 'violent_crime': 3886, 'homicide': 37, 'rape_legacy': 578, 'rape_revised': 598, 'robbery': 268, 'aggravated_assault': 2983, 'property_crime': 28156, 'burglary': 3966, 'larceny': 21427, 'motor_vehicle_theft': 2763, 'arson': 180}end of loop
# {'state_id': 30, 'state_abbr': 'MT', 'year': 2016, 'population': 1038656, 'violent_crime': 3886, 'homicide': 37, 'rape_legacy': 578, 'rape_revised': 598, 'robbery': 268, 'aggravated_assault': 2983, 'property_crime': 28156, 'burglary': 3966, 'larceny': 21427, 'motor_vehicle_theft': 2763, 'arson': 180}end of loop
# {'state_id': 30, 'state_abbr': 'MT', 'year': 2016, 'population': 1038656, 'violent_crime': 3886, 'homicide': 37, 'rape_legacy': 578, 'rape_revised': 598, 'robbery': 268, 'aggravated_assault': 2983, 'property_crime': 28156, 'burglary': 3966, 'larceny': 21427, 'motor_vehicle_theft': 2763, 'arson': 180}end of loop
# {'state_id': 30, 'state_abbr': 'MT', 'year': 2016, 'population': 1038656, 'violent_crime': 3886, 'homicide': 37, 'rape_legacy': 578, 'rape_revised': 598, 'robbery': 268, 'aggravated_assault': 2983, 'property_crime': 28156, 'burglary': 3966, 'larceny': 21427, 'motor_vehicle_theft': 2763, 'arson': 180}end of loop
# {'state_id': 30, 'state_abbr': 'MT', 'year': 2016, 'population': 1038656, 'violent_crime': 3886, 'homicide': 37, 'rape_legacy': 578, 'rape_revised': 598, 'robbery': 268, 'aggravated_assault': 2983, 'property_crime': 28156, 'burglary': 3966, 'larceny': 21427, 'motor_vehicle_theft': 2763, 'arson': 180}end of loop
# {'state_id': 30, 'state_abbr': 'MT', 'year': 2016, 'population': 1038656, 'violent_crime': 3886, 'homicide': 37, 'rape_legacy': 578, 'rape_revised': 598, 'robbery': 268, 'aggravated_assault': 2983, 'property_crime': 28156, 'burglary': 3966, 'larceny': 21427, 'motor_vehicle_theft': 2763, 'arson': 180}end of loop
# {'state_id': 30, 'state_abbr': 'MT', 'year': 2016, 'population': 1038656, 'violent_crime': 3886, 'homicide': 37, 'rape_legacy': 578, 'rape_revised': 598, 'robbery': 268, 'aggravated_assault': 2983, 'property_crime': 28156, 'burglary': 3966, 'larceny': 21427, 'motor_vehicle_theft': 2763, 'arson': 180}end of loop
# {'state_id': 30, 'state_abbr': 'MT', 'year': 2016, 'population': 1038656, 'violent_crime': 3886, 'homicide': 37, 'rape_legacy': 578, 'rape_revised': 598, 'robbery': 268, 'aggravated_assault': 2983, 'property_crime': 28156, 'burglary': 3966, 'larceny': 21427, 'motor_vehicle_theft': 2763, 'arson': 180}end of loop
# {'state_id': 30, 'state_abbr': 'MT', 'year': 2016, 'population': 1038656, 'violent_crime': 3886, 'homicide': 37, 'rape_legacy': 578, 'rape_revised': 598, 'robbery': 268, 'aggravated_assault': 2983, 'property_crime': 28156, 'burglary': 3966, 'larceny': 21427, 'motor_vehicle_theft': 2763, 'arson': 180}end of loop
# {'state_id': 30, 'state_abbr': 'MT', 'year': 2016, 'population': 1038656, 'violent_crime': 3886, 'homicide': 37, 'rape_legacy': 578, 'rape_revised': 598, 'robbery': 268, 'aggravated_assault': 2983, 'property_crime': 28156, 'burglary': 3966, 'larceny': 21427, 'motor_vehicle_theft': 2763, 'arson': 180}end of loop
# {'state_id': 30, 'state_abbr': 'MT', 'year': 2016, 'population': 1038656, 'violent_crime': 3886, 'homicide': 37, 'rape_legacy': 578, 'rape_revised': 598, 'robbery': 268, 'aggravated_assault': 2983, 'property_crime': 28156, 'burglary': 3966, 'larceny': 21427, 'motor_vehicle_theft': 2763, 'arson': 180}end of loop
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-190-956641fdebf2> in <module>
#       1 # Loop through the list of years and perform a request for data on each
#       2 for state in states:
# ----> 3     response = requests.get(base_url + state + post_url).json()['results'][0]
#       4     for offense in fbi_offense:
#       5         state_value.append(state)
#
# KeyError: 'results'

# %%
len(off_year)
# Out:
# 390

# %%
len(off_type)
# Out:
# 390

# %%
len(off_ct)
# Out:
# 390

# %%
# create a data frame from year, offense, and count
fbi_dict = {
    "State": state_value,
    "Offense_Year": off_year,
    "Offense_Type": off_type,
    "Offense_Count": off_ct
}

fbi_data = pd.DataFrame(fbi_dict)
fbi_data.head()
# Out:
#   State  Offense_Year   Offense_Type Offense_Count
# 0    AK          1999       state_id             1
# 1    AK          1999     state_abbr            AK
# 2    AK          1999           year          1999
# 3    AK          1999     population        619500
# 4    AK          1999  violent_crime          3908

# %%
fbi_data.isna().sum()
# Out:
# State             0
# Offense_Year      0
# Offense_Type      0
# Offense_Count    11
# dtype: int64

# %%
fbi_df = fbi_data.dropna()
fbi_df.count()
# Out:
# State            379
# Offense_Year     379
# Offense_Type     379
# Offense_Count    379
# dtype: int64

# %%
# check to see if there are any values that aren't whole numbers (decimals)
all(x.is_integer() for x in fbi_df.Offense_Count)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-197-f7e21346cedd> in <module>
#       1 # check to see if there are any values that aren't whole numbers (decimals)
# ----> 2 all(x.is_integer() for x in fbi_df.Offense_Count)
#
# <ipython-input-197-f7e21346cedd> in <genexpr>(.0)
#       1 # check to see if there are any values that aren't whole numbers (decimals)
# ----> 2 all(x.is_integer() for x in fbi_df.Offense_Count)
#
# AttributeError: 'int' object has no attribute 'is_integer'

# %%
# Export file as a CSV, with the Pandas index and with the header....
fbi_df.to_csv("fbi_data_1998-2017.csv", index=True, header=True)

# %%
fbi_df.head()
# Out:
#   State  Offense_Year   Offense_Type Offense_Count
# 0    AK          1999       state_id             1
# 1    AK          1999     state_abbr            AK
# 2    AK          1999           year          1999
# 3    AK          1999     population        619500
# 4    AK          1999  violent_crime          3908

# %%
# find the cell value within a column with the longest string of text

field_length = fbi_df.Offense_Type.astype(str).map(len)
print(fbi_df.loc[field_length.idxmax(), 'Offense_Type'])
# Out:
# motor_vehicle_theft

# %%
# return the max length of characters in each column

measurer = np.vectorize(len)

res1 = measurer(fbi_df.values.astype(str)).max(axis=0)
res1
# Out:
# array([ 2,  4, 19,  8])
